# %% [markdown]
# # Boilerplate

# %%
# python internal 
import collections
import copy
import gc
from glob import glob
import h5py
import itertools
import os
print(os.getcwd())
import random
import re
import socket
print(socket.gethostname())
import shutil
import subprocess
import sys
# conda/pip
import dask
import graphviz
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy
import seaborn as sns
import tensorflow as tf
from tqdm import tqdm
# special packages on the DIGS
import py3Dmol
import pymol
import pyrosetta
# notebook magic
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# /mnt/home/pleung/projects/bistable_bundle/r3/hinges
# dig100

# %% [markdown]
# # Flo's original approach:
# 5. I design the loops (incl. neighborhood):
# `/home/flop/switch/5thround/DHRs/loops/des*`
# (path names kinda match the ones from loop closure)
# 6. After cleaning up loop neighborhoods with fragment constrained design, stapled using the scripts here `/home/flop/scripts/disulfides/`

# %% [markdown]
# # I will follow Flo's suggestion to do a different order of operations.
# I will use the serialization build of PyRosetta to enable recording user defined info about the designs.
# This enables downstream inline filtering and data analysis, as well as clustering by lineage.
#
# I will rule out designs by stapling prior to loop design cleanup. The resulting designs I will pair.
#
#
# For matching, will try to always find matches for State A as the initial, parent DHR, as this is the gold standard for a reference state.
# Depending on how many matches there are, this might already be enough. But if not, can search through states and find matching length as well as match DSSP and ABEGO
#
# TODO sequence recovery of parent as a final metric in 05?

# %% [markdown]
# # Make functions for looping and labeling to assist downstream penultimate design step

# %%
from pyrosetta.distributed.packed_pose.core import PackedPose
from pyrosetta.distributed import requires_init
from typing import *

@requires_init
def load(silent: str, **kwargs) -> Generator[str, PackedPose, None]:
    """
    Requires init. Because of some issues with silent energies, if your energy 
    is supposed to be a string but is an empty string  (""),
    it will be set to a float value of 0.0
    @pleung
    """
    import pyrosetta
    import pyrosetta.distributed.io as io
    from pyrosetta.rosetta.core.io.silent import SilentFileOptions, SilentFileData
    from pyrosetta.rosetta.core.pose import Pose
    if silent == None:
        silent = kwargs["-in:file:silent"]
    else:
        pass
    options = SilentFileOptions() 
    sfd = SilentFileData(options) # the part that requires init
    sfd.read_file(silent)
    for tag in sfd.tags():
        ss = sfd.get_structure(tag)
        ss_energies = list(ss.energies())
        pose = Pose()
        ss.fill_pose(pose)
        pose.pdb_info().name(tag)
        for energy in ss_energies:
            key = energy.name() 
            # takes advantage of string_value returning "" for true floats
            if energy.string_value() is not "":
                value = energy.string_value() 
            else: # if your energy is supposed to be an empty string it will be set to 0.0 here
                value = energy.value()
            pyrosetta.rosetta.core.pose.setPoseExtraScore(pose, key, value)
        ppose = io.to_packed(pose)
        yield ppose
        
def pack(ppose: PackedPose, **kwargs) -> Generator[str, PackedPose, None]:
    """
    TODO    <OperateOnResidueSubset name="restrict_PRO_GLY" selector="pro_and_gly_positions">
                <PreventRepackingRLT/>
            </OperateOnResidueSubset>
    TODO add csts ?
    TODO play around with neighborhood
    """
    from copy import deepcopy
    import pyrosetta
    import pyrosetta.distributed.io as io
    from pyrosetta.distributed.tasks.rosetta_scripts import SingleoutputRosettaScriptsTask
    scores = deepcopy(ppose.pose.scores)
    new_loop_resis = scores["new_loop_resis"]
    xml = """
    <ROSETTASCRIPTS>
        <SCOREFXNS>
            <ScoreFunction name="sfxn" weights="beta_nov16" >
                <Reweight scoretype="res_type_constraint" weight="1.0" />
            </ScoreFunction> 
        </SCOREFXNS>
        <RESIDUE_SELECTORS>
            <Index name="new_loop_resis" resnums="{new_loop_resis}" />
            <Neighborhood name="around_new_loop" selector="new_loop_resis" distance="6.0" />
            <Or name="designable" selectors="new_loop_resis,around_new_loop" />
            <Neighborhood name="packable" selector="designable" distance="6.0"/>
            <Not name="not_designable" selector="designable" />
            <Not name="not_packable" selector="packable" />
            <ResidueName name="pro_and_gly_positions" residue_name3="PRO,GLY" />
            <Layer name="surface" select_core="false" select_boundary="false" select_surface="true"
                use_sidechain_neighbors="true"/>
            <Layer name="boundary" select_core="false" select_boundary="true" select_surface="false" 
                use_sidechain_neighbors="true"/>
            <Layer name="core" select_core="true" select_boundary="false" select_surface="false" 
                use_sidechain_neighbors="true"/>
            <SecondaryStructure name="sheet" overlap="0" minH="3" minE="2" include_terminal_loops="false" 
                use_dssp="true" ss="E"/>
            <SecondaryStructure name="entire_loop" overlap="0" minH="3" minE="2" include_terminal_loops="true" 
                use_dssp="true" ss="L"/>
            <SecondaryStructure name="entire_helix" overlap="0" minH="3" minE="2" include_terminal_loops="false"
                use_dssp="true" ss="H"/>
            <And name="helix_cap" selectors="entire_loop">
                <PrimarySequenceNeighborhood lower="1" upper="0" selector="entire_helix"/>
            </And>
            <And name="helix_start" selectors="entire_helix">
                <PrimarySequenceNeighborhood lower="0" upper="1" selector="helix_cap"/>
            </And>
            <And name="helix" selectors="entire_helix">
                <Not selector="helix_start"/>
            </And>
            <And name="loop" selectors="entire_loop">
                <Not selector="helix_cap"/>
            </And>
        </RESIDUE_SELECTORS>
        <TASKOPERATIONS>
            <RestrictAbsentCanonicalAAS name="design" keep_aas="ADEFGHIKLMNPQRSTVWY" />
            <OperateOnResidueSubset name="pack" selector="not_designable">
                <RestrictToRepackingRLT/>
            </OperateOnResidueSubset>
            <OperateOnResidueSubset name="lock" selector="not_packable">
                <PreventRepackingRLT/>
            </OperateOnResidueSubset>
            <DesignRestrictions name="layer_design">
                <Action selector_logic="surface AND helix_start"  aas="DEHKPQR"/>
                <Action selector_logic="surface AND helix"        aas="EHKQR"/>
                <Action selector_logic="surface AND sheet"        aas="EHKNQRST"/>
                <Action selector_logic="surface AND loop"         aas="DEGHKNPQRST"/>
                <Action selector_logic="boundary AND helix_start" aas="ADEHIKLNPQRSTVWY"/>
                <Action selector_logic="boundary AND helix"       aas="ADEHIKLNQRSTVWYM"/>
                <Action selector_logic="boundary AND sheet"       aas="DEFHIKLNQRSTVWY"/>
                <Action selector_logic="boundary AND loop"        aas="ADEFGHIKLNPQRSTVWY"/>
                <Action selector_logic="core AND helix_start"     aas="AFILVWYNQSTHP"/>
                <Action selector_logic="core AND helix"           aas="AFILVWM"/>
                <Action selector_logic="core AND sheet"           aas="FILVWY"/>
                <Action selector_logic="core AND loop"            aas="AFGILPVWYSM"/>
                <Action selector_logic="helix_cap"                aas="DNSTP"/>
            </DesignRestrictions>
            <PruneBuriedUnsats name="prune" allow_even_trades="false" 
                atomic_depth_cutoff="3.5" minimum_hbond_energy="-1.0"/>
            <LimitAromaChi2 name="arochi" chi2max="110" chi2min="70" include_trp="True" />
            <ExtraRotamersGeneric name="ex1_ex2" ex1="1" ex2="1" />
        </TASKOPERATIONS>
        <MOVERS>
            <StructProfileMover name="gen_profile" add_csts_to_pose="1" consider_topN_frags="100" 
                eliminate_background="0" ignore_terminal_residue="1" only_loops="0"
                residue_selector="designable" burialWt="0" RMSthreshold="0.6" />
            <ClearConstraintsMover name="clear_constraints" />
            <PackRotamersMover name="pack"
            task_operations="arochi,prune,ex1_ex2,design,pack,lock,layer_design"/>
        </MOVERS>
        <PROTOCOLS>
            <Add mover="gen_profile"/>
            <Add mover="pack"/>
            <Add mover="clear_constraints"/>
        </PROTOCOLS>
    </ROSETTASCRIPTS>
    """.format(new_loop_resis=new_loop_resis)
    pack = SingleoutputRosettaScriptsTask(xml)
    pack_ppose = pack(ppose.pose.clone())
    pose = io.to_pose(pack_ppose)
    for key, value in scores.items():
        pyrosetta.rosetta.core.pose.setPoseExtraScore(pose, key, value)
    final_ppose = io.to_packed(pose)
    yield final_ppose
        
def staple(ppose: PackedPose, **kwargs) -> list:
    """
    TODO ~90% of all native disulfides have an energy of less than -0.8 given the standard 1.25 weight (Ref2015).
    TODO other params like cutoff for stapler?
    TODO assumes middle is where the switch is split originally
    """
    from copy import deepcopy
    import pyrosetta
    import pyrosetta.distributed.io as io
    from pyrosetta.distributed.tasks.rosetta_scripts import SingleoutputRosettaScriptsTask
    from pyrosetta.rosetta.protocols.rosetta_scripts import XmlObjects
    from stapler import NativeDisulfideStapler
    scores = deepcopy(ppose.pose.scores)
    pose = io.to_pose(ppose.pose.clone())
    new_loop_resis = [int(x) for x in scores["new_loop_resis"].split(",")]
    new_loop_resis.sort()
    print("new loop found at indices", new_loop_resis)
    upper_A = new_loop_resis[0] - 4
    lower_B = new_loop_resis[-1] + 4
    try:
        assert upper_A > 0
        assert lower_B < len(pose.residues)
    except AssertionError:
        print("the new loop resis are unexpectedly close to the termini")
    selectors = XmlObjects.create_from_string(
        """
        <RESIDUE_SELECTORS>
            <SSElement name="first" selection="n_term" to_selection="{pre},H,E" chain="A" reassign_short_terminal_loop="2" />
            <SSElement name="second" selection="{post},H,S" to_selection="c_term" chain="A" reassign_short_terminal_loop="2" />
        </RESIDUE_SELECTORS>
        """.format(
            pre = int(scores["pre_break_helix"]),
            post = int(scores["pre_break_helix"]+1)
        )
    )
    first = selectors.get_residue_selector("first")
    second = selectors.get_residue_selector("second")
    first_resis = list(first.apply(pose))
    second_resis = list(second.apply(pose))
    chunk_A = pyrosetta.rosetta.core.select.residue_selector.ResidueIndexSelector()
    chunk_B = pyrosetta.rosetta.core.select.residue_selector.ResidueIndexSelector()
    offset = 3 # distance we want to stay away from new loop
    length = len(pose.residues)
    assert length == scores["total_length"] 
    for i, index_bool in enumerate(first_resis, start=1):
        # don't add residues within offset distance before new loop
        if index_bool and i < (sum(first_resis) - offset):
            chunk_A.append_index(i)
        else:
            pass
    for i, index_bool in enumerate(second_resis, start=1):
        first = 0
        # don't add residues within offset distance after new loop
        if index_bool and i > (sum(1 for x in second_resis if not x) + offset):
            chunk_B.append_index(i)
        else:
            pass
    not_too_close = [chunk_B, chunk_A]
    
    new_loop_resis = scores["new_loop_resis"]
    # TODO
    #previous version used 0.6 for pertscale. i think i might want to make this a little crazier.
    #I also want to play around with turning off the constraints that pull it back to the native conformation
    #prev nmodes=5, perscale=0.6, mm=false
    #let's try again doing it all at once
    #and relaxmode has 3 options: relax, min, and extrapolate. I think min is still wise, but extrapolate might be fun
    # TODO, changing helix indexing to improve accuracy
    xml = """
    <ROSETTASCRIPTS>
        <SCOREFXNS>
        <ScoreFunction name="sfxn" weights="beta_nov16"/>
        <ScoreFunction name="sfxn_bb_perterb" weights="beta_nov16">
            <Reweight scoretype="coordinate_constraint" weight="5.0"/> #play with this
        </ScoreFunction>
        </SCOREFXNS>
        <RESIDUE_SELECTORS>
            <True name="all"/>
            <SSElement name="design" selection="{pre},H,S" to_selection="-{post},H,E" chain="A" reassign_short_terminal_loop="2" />            
            <Not name="not_design" selector="design"/>
            <Neighborhood name="pack" selector="design" distance="8.0" include_focus_in_subset="0"/>
            <Not name="not_pack" selector="pack"/>
            <And name="lock_selector" selectors="not_pack,not_design"/>
        </RESIDUE_SELECTORS>
        <TASKOPERATIONS>
            <OperateOnResidueSubset name="lock" selector="lock_selector">
                <PreventRepackingRLT/>
            </OperateOnResidueSubset>
        </TASKOPERATIONS>
        <MOVERS>
            <NormalModeRelax name="normal_modes"
                cartesian="true"
                centroid="false"
                nmodes="3"
                scorefxn="sfxn"
                mix_modes="true"
                pertscale="1.6"
                randomselect="true"
                relaxmode="relax"
                cartesian_minimize="false" >
                <MoveMap name="mm" bb="false" chi="false" jump="false" >
                    <ResidueSelector selector="all" bb="false" chi="false" />
                    <ResidueSelector selector="pack" bb="false" chi="true" />
                    <ResidueSelector selector="design" bb="true" chi="true" />
                </MoveMap>
            </NormalModeRelax>
        </MOVERS>
        <PROTOCOLS>
            <Add mover="normal_modes"/>
        </PROTOCOLS>
    </ROSETTASCRIPTS>
    """.format(
        pre = int(scores["pre_break_helix"]-1),
        post = int(scores["pre_break_helix"]-1)
    )
    normal_modes = SingleoutputRosettaScriptsTask(xml)
    # initialize the native disulfide stapler with defaults.
    stapler = NativeDisulfideStapler(
        residue_selectors = not_too_close,
    )
    for i in range(10): # TODO
        crosslinked_poses = stapler.apply(pose) # this returns a generator
        try: # peek inside the generator to see if it is empty
            peek = next(crosslinked_poses) # raises StopIteration exception if empty
            break # break out of the loop if it isn't empty
        except StopIteration: # perform normal modes relax if StopIteration exception occurs
            pose = io.to_pose(normal_modes(pose))
    name = pose.pdb_info().name()
    poses = []
    sfxn = pyrosetta.rosetta.protocols.loops.get_fa_scorefxn() 
    for i, crosslinked_pose in enumerate(crosslinked_poses):
        suffix = "_" + str(i)
        crosslinked_pose.pdb_info().name(name+suffix)
        sfxn.score(crosslinked_pose)
        dslf_fa13 = crosslinked_pose.scores["dslf_fa13"]
        disulfide = []
        for i, aa in enumerate(crosslinked_pose.sequence(), start=1):
            if aa == "C":
                disulfide.append(str(i))
            else:
                pass
        assert len(disulfide) == 2
        disulfide_str = ",".join(disulfide)
        pyrosetta.rosetta.core.pose.setPoseExtraScore(crosslinked_pose, "disulfide_at", disulfide_str)
        for key, value in scores.items():
            pyrosetta.rosetta.core.pose.setPoseExtraScore(crosslinked_pose, key, value)
        pyrosetta.rosetta.core.pose.setPoseExtraScore(crosslinked_pose, "dslf_fa13", dslf_fa13)
        poses.append(crosslinked_pose)
    if len(poses) > 0:
        final_pposes = io.to_packed(set(poses))
    else:
        final_pposes = {}
    return final_pposes

def check_disulf_energy(ppose: PackedPose, **kwargs) -> PackedPose:
    """
    relax the pose around the interface in cartesian space, but don't save it, keep the original pose,
    get the cartesian-relaxed disulfide scores and rmsd, 
    and add them the original pose with the original scores
    TODO assumes middle is where the switch is split originally
    @pleung
    """
    from copy import deepcopy
    import pyrosetta
    import pyrosetta.distributed.io as io
    from pyrosetta.distributed.tasks.rosetta_scripts import SingleoutputRosettaScriptsTask
    scores = deepcopy(ppose.pose.scores)
    xml = """
    <ROSETTASCRIPTS>
        <SCOREFXNS>
            <ScoreFunction name="sfxn_cart" weights="ref2015_cart" /> 
            <ScoreFunction name="sfxn" weights="ref2015" /> 
        </SCOREFXNS>
        <RESIDUE_SELECTORS>
            <True name="all"/>
            <SSElement name="design" selection="{pre},H,S" to_selection="-{post},H,E" chain="A" reassign_short_terminal_loop="2" />            
            <Not name="not_design" selector="design"/>
            <Neighborhood name="pack" selector="design" distance="8.0" include_focus_in_subset="0"/>
            <Not name="not_pack" selector="pack"/>
            <And name="lock_selector" selectors="not_pack,not_design"/>
        </RESIDUE_SELECTORS>
        <TASKOPERATIONS>
            <PruneBuriedUnsats name="prune" allow_even_trades="false" 
                atomic_depth_cutoff="3.5" minimum_hbond_energy="-1.0"/>
            <LimitAromaChi2 name="arochi" chi2max="110" chi2min="70" include_trp="True" />
            <ExtraRotamersGeneric name="ex1_ex2" ex1="1" ex2="1" />
            <OperateOnResidueSubset name="lock" selector="lock_selector">
                <PreventRepackingRLT/>
            </OperateOnResidueSubset>
        </TASKOPERATIONS>
        <FILTERS>
            <Rmsd name="rmsd_cart" reference_name="before_relax" chains="A" superimpose="0" threshold="5" by_aln="0" confidence="0" />
        </FILTERS>
        <MOVERS>
            <SavePoseMover name="save_before_relax" restore_pose="0" reference_name="before_relax"/>
            <FastRelax name="relax" scorefxn="sfxn_cart"
                task_operations="arochi,prune,ex1_ex2,lock"
                repeats="2" 
                relaxscript="MonomerRelax2019"
                cartesian="true"
                bondangle="true"
                bondlength="true" >
                    <MoveMap name="mm" bb="false" chi="false" jump="false" >
                        <ResidueSelector selector="all" bb="false" chi="false" bondangle="false" bondlength="false" />
                        <ResidueSelector selector="pack" bb="false" chi="true" bondangle="true" bondlength="true" />
                        <ResidueSelector selector="design" bb="true" chi="true" bondangle="true" bondlength="true" />
                    </MoveMap>
            </FastRelax>
        </MOVERS>
        <PROTOCOLS>
            <Add mover="save_before_relax" />
            <Add mover="relax" />            
            <Add filter="rmsd_cart" />            
        </PROTOCOLS>
        <OUTPUT scorefxn="sfxn" />
    </ROSETTASCRIPTS>
    """.format(
        pre = int(scores["pre_break_helix"]-1),
        post = int(scores["pre_break_helix"]-1)
    )
    relax = SingleoutputRosettaScriptsTask(xml)
    # relax the pose to get scores
    relax_ppose = relax(ppose.pose.clone())
    # keep the original pose...
    pose = io.to_pose(ppose)
    # ... get the cartesian-relaxed disulfide scores and rmsd...
    update = deepcopy(relax_ppose.pose.scores)
    dslf_fa13_cart = update["dslf_fa13"]
    rmsd_cart = update["rmsd_cart"]
    # ... add the original scores ...
    for key, value in scores.items():
        pyrosetta.rosetta.core.pose.setPoseExtraScore(pose, key, value)
    # ... and finally add the cartesian-relaxed disulfide scores and rmsd
    pyrosetta.rosetta.core.pose.setPoseExtraScore(pose, "dslf_fa13_cart", dslf_fa13_cart)
    pyrosetta.rosetta.core.pose.setPoseExtraScore(pose, "rmsd_cart", rmsd_cart)
    final_ppose = io.to_packed(pose)
    return final_ppose

def relax(ppose: PackedPose, **kwargs) -> PackedPose:
    """
    dualspace relax, check rmsd and fragment quality and return scored ppose
    geometry filter counts bad residues.
    TODO assumes middle is where the switch is split originally
    @pleung
    """
    from copy import deepcopy
    import pyrosetta
    import pyrosetta.distributed.io as io
    from pyrosetta.distributed.tasks.rosetta_scripts import SingleoutputRosettaScriptsTask
    scores = deepcopy(ppose.pose.scores)
    new_loop_resis = scores["new_loop_resis"]
    xml = """
    <ROSETTASCRIPTS>
        <SCOREFXNS>
            <ScoreFunction name="sfxn" weights="beta_nov16" /> 
            <ScoreFunction name="sfxn_cart" weights="beta_nov16_cart" /> 
        </SCOREFXNS>
        <RESIDUE_SELECTORS>
            <True name="all"/>
            <ResidueName name="CYS" residue_name3="CYS,CYD" />
            <Not name="not_CYS" selector="CYS" />
            <Index name="new_loop_resis" resnums="{new_loop_resis}" />
            <Neighborhood name="around_new_loop" selector="new_loop_resis" distance="8.0" />
            <SSElement name="design" selection="{pre},H,S" to_selection="-{post},H,E" chain="A" reassign_short_terminal_loop="2" />            
            <Not name="not_design" selector="design"/>
            <Neighborhood name="pack" selector="design" distance="8.0" include_focus_in_subset="0"/>
            <Not name="not_pack" selector="pack"/>
            <And name="lock_selector" selectors="not_pack,not_design"/>
        </RESIDUE_SELECTORS>
        <TASKOPERATIONS>
            <PruneBuriedUnsats name="prune" allow_even_trades="false" 
                atomic_depth_cutoff="3.5" minimum_hbond_energy="-1.0"/>
            <LimitAromaChi2 name="arochi" chi2max="110" chi2min="70" include_trp="True" />
            <ExtraRotamersGeneric name="ex1_ex2" ex1="1" ex2="1" />
            <OperateOnResidueSubset name="lock" selector="lock_selector">
                <PreventRepackingRLT/>
            </OperateOnResidueSubset>
        </TASKOPERATIONS>
        <FILTERS>
            FragQual name="frag_qual" confidence="0" />
            <Geometry name="geometry"
            confidence="0"
            count_bad_residues="true" />
            <Geometry name="geometry_loop" 
            residue_selector="around_new_loop" 
            confidence="0"
            count_bad_residues="true" />
            <Rmsd name="rmsd_dual" reference_name="before_relax" chains="A" superimpose="0" threshold="5" by_aln="0" confidence="0" />
            <worst9mer name="9mer" rmsd_lookup_threshold="0.4" confidence="0" />
        </FILTERS>
        <MOVERS>
            <SavePoseMover name="save_before_relax" restore_pose="0" reference_name="before_relax"/>
            <FastRelax name="relax" scorefxn="sfxn_cart"
                task_operations="arochi,prune,ex1_ex2,lock"
                repeats="2" 
                relaxscript="MonomerRelax2019"
                dualspace="true"
                bondangle="true"
                bondlength="true" >
                <MoveMap name="mm" bb="false" chi="false" jump="false" >
                    <ResidueSelector selector="all" bb="false" chi="false" bondangle="false" bondlength="false" />
                    <ResidueSelector selector="pack" bb="false" chi="true" bondangle="false" bondlength="false" />
                    <ResidueSelector selector="design" bb="true" chi="true" bondangle="false" bondlength="false" />
                    <ResidueSelector selector="CYS" bb="true" chi="true" bondangle="true" bondlength="true" />
                </MoveMap>
            </FastRelax>
        </MOVERS>
        <PROTOCOLS>
            <Add mover="save_before_relax" />
            <Add mover="relax" />
            <Add filter="geometry" />
            <Add filter="geometry_loop" />
            <Add filter="rmsd_dual" />
            <Add filter="9mer" />
        </PROTOCOLS>
        <OUTPUT scorefxn="sfxn" />
    </ROSETTASCRIPTS>
    """.format(
        new_loop_resis=new_loop_resis,
        pre = int(scores["pre_break_helix"]-1),
        post = int(scores["pre_break_helix"]-1)
    )
    # relax and score pose
    relax = SingleoutputRosettaScriptsTask(xml)
    relax_ppose = relax(ppose.pose.clone())
    pose = io.to_pose(relax_ppose)
    update = deepcopy(pose.scores)
    # update scores for values that were updated
    for key, value in scores.items():
        if key in update.keys():
            pyrosetta.rosetta.core.pose.setPoseExtraScore(pose, key, update[key])
        else:
            pyrosetta.rosetta.core.pose.setPoseExtraScore(pose, key, value)
    final_ppose = io.to_packed(pose)
    return final_ppose

# %%
pyrosetta.init("-run:constant_seed 1 -corrections::beta_nov16 true -indexed_structure_store:fragment_store /net/databases/VALL_clustered/connect_chains/ss_grouped_vall_helix_shortLoop.h5")
stapled = []
for i, tppose in enumerate(load("03_silents/closed.silent")):
    if i > 3: 
        break
    else:
        pass
    test = next(pack(tppose))
    stapled.append(staple(test))
# Out:
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -515.232  1.03554  1.03554  0.30745
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -508.934  1.03554  1.03554  0.31955
# protocols.relax.FastRelax: {0} CMD: min  -524.068  0.982319  0.982319  0.31955
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -524.068  0.982319  0.982319  0.31955
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -436.004  0.982319  0.982319  0.55
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 3489 rotamers at 200 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -437.222  0.982319  0.982319  0.55
# protocols.relax.FastRelax: {0} CMD: min  -467.44  0.992009  0.992009  0.55
# protocols.relax.FastRelax: {0} MRP: 0  -467.44  -467.44  0.992009  0.992009
# protocols.relax.FastRelax: {0} CMD: accept_to_best  -467.44  0.992009  0.992009  0.55
# protocols.relax.FastRelax: {0} CMD: endrepeat  -467.44  0.992009  0.992009  0.55
# protocols::checkpoint: {0} Deleting checkpoints of FastRelax
# protocols.normalmode.NormalModeRelaxMover: {0} Rmsd: initial vs relaxed: 0.992009
# protocols.normalmode.NormalModeRelaxMover: {0} Rmsd: extrapolated vs relaxed: -nan
# protocols.normalmode.NormalModeRelaxMover: {0} score: -505.982
# protocols.normalmode.NormalModeRelaxMover: {0} printing mode_scales
# protocols.normalmode.NormalModeRelaxMover: {0} [0.294107, 0.667412, -0.800694]
# protocols.normalmode.NormalModeRelaxMover: {0} Normal mode for mode no 3  0.27155  0.61622 -0.73928
# protocols.normalmode.NormalModeRelaxMover: {0} Solving Normal Mode for given pose...
# protocols.normalmode.NormalMode: {0} Solving Cartesian Normal Mode, Distance cut set as 10, using uniform spring constants:1
# protocols.normalmode.NormalMode: {0} Diagonalization done.
# protocols.normalmode.NormalModeRelaxMover: {0} NM solved in 0.257724 sec.
# protocols.normalmode.NormalModeRelaxMover: {0} CNM, Dynamic scale for set as 15.5949, given moving distance 1.6
# protocols.relax.FastRelax: {0} CMD: repeat  -235.291  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -235.291  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -373.784  0  0  0.022
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 4124 rotamers at 200 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -406.675  0  0  0.022
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -401.598  0  0  0.02805
# protocols.relax.FastRelax: {0} CMD: min  -579.207  0.803829  0.803829  0.02805
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -579.207  0.803829  0.803829  0.02805
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -376.02  0.803829  0.803829  0.14575
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 3770 rotamers at 200 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -412.463  0.803829  0.803829  0.14575
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -401.288  0.803829  0.803829  0.154
# protocols.relax.FastRelax: {0} CMD: min  -489.956  0.763761  0.763761  0.154
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -489.956  0.763761  0.763761  0.154
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -409.332  0.763761  0.763761  0.30745
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 3630 rotamers at 200 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -411.164  0.763761  0.763761  0.30745
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -405.072  0.763761  0.763761  0.31955
# protocols.relax.FastRelax: {0} CMD: min  -421.167  0.736773  0.736773  0.31955
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -421.167  0.736773  0.736773  0.31955
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -337.948  0.736773  0.736773  0.55
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 3539 rotamers at 200 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -339.219  0.736773  0.736773  0.55
# protocols.relax.FastRelax: {0} CMD: min  -369.301  0.70647  0.70647  0.55
# protocols.relax.FastRelax: {0} MRP: 0  -369.301  -369.301  0.70647  0.70647
# protocols.relax.FastRelax: {0} CMD: accept_to_best  -369.301  0.70647  0.70647  0.55
# protocols.relax.FastRelax: {0} CMD: endrepeat  -369.301  0.70647  0.70647  0.55
# protocols::checkpoint: {0} Deleting checkpoints of FastRelax
# protocols.normalmode.NormalModeRelaxMover: {0} Rmsd: initial vs relaxed: 0.70647
# protocols.normalmode.NormalModeRelaxMover: {0} Rmsd: extrapolated vs relaxed: -nan
# protocols.normalmode.NormalModeRelaxMover: {0} score: -509.991
# protocols.normalmode.NormalModeRelaxMover: {0} printing mode_scales
# protocols.normalmode.NormalModeRelaxMover: {0} [-0.360735, -0.590771, 0.346451]
# protocols.normalmode.NormalModeRelaxMover: {0} Normal mode for mode no 4 -0.46603 -0.76321  0.44758
# protocols.normalmode.NormalModeRelaxMover: {0} Solving Normal Mode for given pose...
# protocols.normalmode.NormalMode: {0} Solving Cartesian Normal Mode, Distance cut set as 10, using uniform spring constants:1
# protocols.normalmode.NormalMode: {0} Diagonalization done.
# protocols.normalmode.NormalModeRelaxMover: {0} NM solved in 0.255605 sec.
# protocols.normalmode.NormalModeRelaxMover: {0} CNM, Dynamic scale for set as 15.5949, given moving distance 1.6
# protocols.relax.FastRelax: {0} CMD: repeat  -235.291  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -235.291  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -373.784  0  0  0.022
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 4124 rotamers at 200 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -409.85  0  0  0.022
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -405.079  0  0  0.02805
# protocols.relax.FastRelax: {0} CMD: min  -623.565  1.01873  1.01873  0.02805
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -623.565  1.01873  1.01873  0.02805
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -394.621  1.01873  1.01873  0.14575
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 3666 rotamers at 200 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -414.052  1.01873  1.01873  0.14575
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -401.017  1.01873  1.01873  0.154
# protocols.relax.FastRelax: {0} CMD: min  -508.15  0.842747  0.842747  0.154
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -508.15  0.842747  0.842747  0.154
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -424.829  0.842747  0.842747  0.30745
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 3535 rotamers at 200 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -425.339  0.842747  0.842747  0.30745
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -418.932  0.842747  0.842747  0.31955
# protocols.relax.FastRelax: {0} CMD: min  -436.221  0.801294  0.801294  0.31955
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -436.221  0.801294  0.801294  0.31955
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -349.731  0.801294  0.801294  0.55
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 3441 rotamers at 200 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -352.468  0.801294  0.801294  0.55
# protocols.relax.FastRelax: {0} CMD: min  -386.204  0.863211  0.863211  0.55
# protocols.relax.FastRelax: {0} MRP: 0  -386.204  -386.204  0.863211  0.863211
# protocols.relax.FastRelax: {0} CMD: accept_to_best  -386.204  0.863211  0.863211  0.55
# protocols.relax.FastRelax: {0} CMD: endrepeat  -386.204  0.863211  0.863211  0.55
# protocols::checkpoint: {0} Deleting checkpoints of FastRelax
# protocols.normalmode.NormalModeRelaxMover: {0} Rmsd: initial vs relaxed: 0.863211
# protocols.normalmode.NormalModeRelaxMover: {0} Rmsd: extrapolated vs relaxed: 0.64591
# protocols.normalmode.NormalModeRelaxMover: {0} score: -500.830
# protocols.normalmode.NormalModeRelaxMover: {0} printing mode_scales
# protocols.normalmode.NormalModeRelaxMover: {0} [0.902763, 0.370143, -0.535245]
# protocols.normalmode.NormalModeRelaxMover: {0} Normal mode for mode no 5  0.81120  0.33260 -0.48096
# protocols.normalmode.NormalModeRelaxMover: {0} Solving Normal Mode for given pose...
# protocols.normalmode.NormalMode: {0} Solving Cartesian Normal Mode, Distance cut set as 10, using uniform spring constants:1
# protocols.normalmode.NormalMode: {0} Diagonalization done.
# protocols.normalmode.NormalModeRelaxMover: {0} NM solved in 0.252081 sec.
# protocols.normalmode.NormalModeRelaxMover: {0} CNM, Dynamic scale for set as 15.5949, given moving distance 1.6
# protocols.relax.FastRelax: {0} CMD: repeat  -235.291  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -235.291  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -373.784  0  0  0.022
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 4124 rotamers at 200 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -407.887  0  0  0.022
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -402.078  0  0  0.02805
# protocols.relax.FastRelax: {0} CMD: min  -588.04  0.832539  0.832539  0.02805
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -588.04  0.832539  0.832539  0.02805
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -366.426  0.832539  0.832539  0.14575
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 3753 rotamers at 200 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -386.268  0.832539  0.832539  0.14575
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -373.646  0.832539  0.832539  0.154
# protocols.relax.FastRelax: {0} CMD: min  -486.519  0.718504  0.718504  0.154
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -486.519  0.718504  0.718504  0.154
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -406.973  0.718504  0.718504  0.30745
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 3657 rotamers at 200 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -400.094  0.718504  0.718504  0.30745
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -393.918  0.718504  0.718504  0.31955
# protocols.relax.FastRelax: {0} CMD: min  -411.146  0.65175  0.65175  0.31955
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -411.146  0.65175  0.65175  0.31955
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -328.596  0.65175  0.65175  0.55
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 3550 rotamers at 200 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -330.361  0.65175  0.65175  0.55
# protocols.relax.FastRelax: {0} CMD: min  -358.46  0.707655  0.707655  0.55
# protocols.relax.FastRelax: {0} MRP: 0  -358.46  -358.46  0.707655  0.707655
# protocols.relax.FastRelax: {0} CMD: accept_to_best  -358.46  0.707655  0.707655  0.55
# protocols.relax.FastRelax: {0} CMD: endrepeat  -358.46  0.707655  0.707655  0.55
# protocols::checkpoint: {0} Deleting checkpoints of FastRelax
# protocols.normalmode.NormalModeRelaxMover: {0} Rmsd: initial vs relaxed: 0.707655
# protocols.normalmode.NormalModeRelaxMover: {0} Rmsd: extrapolated vs relaxed: -nan
# protocols.normalmode.NormalModeRelaxMover: {0} score: -503.620
# protocols.normalmode.NormalModeRelaxMover: {0} printing mode_scales
# protocols.normalmode.NormalModeRelaxMover: {0} [-0.149003, -0.694724, -0.0776641]
# protocols.normalmode.NormalModeRelaxMover: {0} Normal mode for mode no 6 -0.20847 -0.97197 -0.10866
# protocols.normalmode.NormalModeRelaxMover: {0} Solving Normal Mode for given pose...
# protocols.normalmode.NormalMode: {0} Solving Cartesian Normal Mode, Distance cut set as 10, using uniform spring constants:1
# protocols.normalmode.NormalMode: {0} Diagonalization done.
# protocols.normalmode.NormalModeRelaxMover: {0} NM solved in 0.255044 sec.
# protocols.normalmode.NormalModeRelaxMover: {0} CNM, Dynamic scale for set as 15.5949, given moving distance 1.6
# protocols.relax.FastRelax: {0} CMD: repeat  -235.291  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -235.291  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -373.784  0  0  0.022
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 4124 rotamers at 200 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -408.43  0  0  0.022
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -403.598  0  0  0.02805
# protocols.relax.FastRelax: {0} CMD: min  -664.92  1.2409  1.2409  0.02805
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -664.92  1.2409  1.2409  0.02805
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -441.713  1.2409  1.2409  0.14575
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 3707 rotamers at 200 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -483.144  1.2409  1.2409  0.14575
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -471.177  1.2409  1.2409  0.154
# protocols.relax.FastRelax: {0} CMD: min  -576.854  1.10987  1.10987  0.154
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -576.854  1.10987  1.10987  0.154
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -494.633  1.10987  1.10987  0.30745
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 3574 rotamers at 200 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -494.015  1.10987  1.10987  0.30745
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -487.706  1.10987  1.10987  0.31955
# protocols.relax.FastRelax: {0} CMD: min  -505.893  1.07031  1.07031  0.31955
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -505.893  1.07031  1.07031  0.31955
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -421.579  1.07031  1.07031  0.55
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 3483 rotamers at 200 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -422.58  1.07031  1.07031  0.55
# protocols.relax.FastRelax: {0} CMD: min  -450.604  1.06948  1.06948  0.55
# protocols.relax.FastRelax: {0} MRP: 0  -450.604  -450.604  1.06948  1.06948
# protocols.relax.FastRelax: {0} CMD: accept_to_best  -450.604  1.06948  1.06948  0.55
# protocols.relax.FastRelax: {0} CMD: endrepeat  -450.604  1.06948  1.06948  0.55
# protocols::checkpoint: {0} Deleting checkpoints of FastRelax
# protocols.normalmode.NormalModeRelaxMover: {0} Rmsd: initial vs relaxed: 1.06948
# protocols.normalmode.NormalModeRelaxMover: {0} Rmsd: extrapolated vs relaxed: 0.487142
# protocols.normalmode.NormalModeRelaxMover: {0} score: -507.805
# protocols.normalmode.NormalModeRelaxMover: {0} final pose with score -500.830
# protocols.rosetta_scripts.ParsedProtocol: {0} setting status to success
# ((89, 'CYS', (-90.0,)), (108, 'CYS', (-150.0,)))
# core.scoring.ScoreFunctionFactory: {0} SCOREFUNCTION: beta_nov16.wts
# ((89, 'CYS', (-60.0,)), (108, 'CYS', (-150.0,)))
# ((108, 'CYS', (-180.0,)), (89, 'CYS', (-60.0,)))
# ((89, 'CYS', (-90.0,)), (108, 'CYS', (-180.0,)))
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Validating input script...
# protocols.rosetta_scripts.RosettaScriptsParser: {0} ...done
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Parsed script:
# <ROSETTASCRIPTS>
# 	<SCOREFXNS>
# 		<ScoreFunction name="sfxn" weights="beta_nov16">
# 			<Reweight scoretype="res_type_constraint" weight="1.0"/>
# 		</ScoreFunction>
# 	</SCOREFXNS>
# 	<RESIDUE_SELECTORS>
# 		<Index name="new_loop_resis" resnums="98,99,100"/>
# 		<Neighborhood distance="6.0" name="around_new_loop" selector="new_loop_resis"/>
# 		<Or name="designable" selectors="new_loop_resis,around_new_loop"/>
# 		<Neighborhood distance="6.0" name="packable" selector="designable"/>
# 		<Not name="not_designable" selector="designable"/>
# 		<Not name="not_packable" selector="packable"/>
# 		<ResidueName name="pro_and_gly_positions" residue_name3="PRO,GLY"/>
# 		<Layer name="surface" select_boundary="false" select_core="false" select_surface="true" use_sidechain_neighbors="true"/>
# 		<Layer name="boundary" select_boundary="true" select_core="false" select_surface="false" use_sidechain_neighbors="true"/>
# 		<Layer name="core" select_boundary="false" select_core="true" select_surface="false" use_sidechain_neighbors="true"/>
# 		<SecondaryStructure include_terminal_loops="false" minE="2" minH="3" name="sheet" overlap="0" ss="E" use_dssp="true"/>
# 		<SecondaryStructure include_terminal_loops="true" minE="2" minH="3" name="entire_loop" overlap="0" ss="L" use_dssp="true"/>
# 		<SecondaryStructure include_terminal_loops="false" minE="2" minH="3" name="entire_helix" overlap="0" ss="H" use_dssp="true"/>
# 		<And name="helix_cap" selectors="entire_loop">
# 			<PrimarySequenceNeighborhood lower="1" selector="entire_helix" upper="0"/>
# 		</And>
# 		<And name="helix_start" selectors="entire_helix">
# 			<PrimarySequenceNeighborhood lower="0" selector="helix_cap" upper="1"/>
# 		</And>
# 		<And name="helix" selectors="entire_helix">
# 			<Not selector="helix_start"/>
# 		</And>
# 		<And name="loop" selectors="entire_loop">
# 			<Not selector="helix_cap"/>
# 		</And>
# 	</RESIDUE_SELECTORS>
# 	<TASKOPERATIONS>
# 		<RestrictAbsentCanonicalAAS keep_aas="ADEFGHIKLMNPQRSTVWY" name="design"/>
# 		<OperateOnResidueSubset name="pack" selector="not_designable">
# 			<RestrictToRepackingRLT/>
# 		</OperateOnResidueSubset>
# 		<OperateOnResidueSubset name="lock" selector="not_packable">
# 			<PreventRepackingRLT/>
# 		</OperateOnResidueSubset>
# 		<DesignRestrictions name="layer_design">
# 			<Action aas="DEHKPQR" selector_logic="surface AND helix_start"/>
# 			<Action aas="EHKQR" selector_logic="surface AND helix"/>
# 			<Action aas="EHKNQRST" selector_logic="surface AND sheet"/>
# 			<Action aas="DEGHKNPQRST" selector_logic="surface AND loop"/>
# 			<Action aas="ADEHIKLNPQRSTVWY" selector_logic="boundary AND helix_start"/>
# 			<Action aas="ADEHIKLNQRSTVWYM" selector_logic="boundary AND helix"/>
# 			<Action aas="DEFHIKLNQRSTVWY" selector_logic="boundary AND sheet"/>
# 			<Action aas="ADEFGHIKLNPQRSTVWY" selector_logic="boundary AND loop"/>
# 			<Action aas="AFILVWYNQSTHP" selector_logic="core AND helix_start"/>
# 			<Action aas="AFILVWM" selector_logic="core AND helix"/>
# 			<Action aas="FILVWY" selector_logic="core AND sheet"/>
# 			<Action aas="AFGILPVWYSM" selector_logic="core AND loop"/>
# 			<Action aas="DNSTP" selector_logic="helix_cap"/>
# 		</DesignRestrictions>
# 		<PruneBuriedUnsats allow_even_trades="false" atomic_depth_cutoff="3.5" minimum_hbond_energy="-1.0" name="prune"/>
# 		<LimitAromaChi2 chi2max="110" chi2min="70" include_trp="True" name="arochi"/>
# 		<ExtraRotamersGeneric ex1="1" ex2="1" name="ex1_ex2"/>
# 	</TASKOPERATIONS>
# 	<MOVERS>
# 		<StructProfileMover RMSthreshold="0.6" add_csts_to_pose="1" burialWt="0" consider_topN_frags="100" eliminate_background="0" ignore_terminal_residue="1" name="gen_profile" only_loops="0" residue_selector="designable"/>
# 		<ClearConstraintsMover name="clear_constraints"/>
# 		<PackRotamersMover name="pack" task_operations="arochi,prune,ex1_ex2,design,pack,lock,layer_design"/>
# 	</MOVERS>
# 	<PROTOCOLS>
# 		<Add mover="gen_profile"/>
# 		<Add mover="pack"/>
# 		<Add mover="clear_constraints"/>
# 	</PROTOCOLS>
# </ROSETTASCRIPTS>
# core.scoring.ScoreFunctionFactory: {0} SCOREFUNCTION: beta_nov16.wts
# protocols.jd2.parser.ScoreFunctionLoader: {0} defined score function "sfxn" with weights "beta_nov16"
# protocols.jd2.parser.ScoreFunctionLoader: {0}  setting sfxn weight res_type_constraint to 1
# core.select.residue_selector.LayerSelector: {0} Setting LayerSelector to use sidechain neighbors to determine burial.
# core.select.residue_selector.LayerSelector: {0} Set cutoffs for core and surface to 5.2 and 2, respectively, in LayerSelector.
# core.select.residue_selector.LayerSelector: {0} Setting core=false boundary=false surface=true in LayerSelector.
# core.select.residue_selector.LayerSelector: {0} Setting LayerSelector to use sidechain neighbors to determine burial.
# core.select.residue_selector.LayerSelector: {0} Set cutoffs for core and surface to 5.2 and 2, respectively, in LayerSelector.
# core.select.residue_selector.LayerSelector: {0} Setting LayerSelector to use sidechain neighbors to determine burial.
# core.select.residue_selector.LayerSelector: {0} Set cutoffs for core and surface to 5.2 and 2, respectively, in LayerSelector.
# core.select.residue_selector.LayerSelector: {0} Setting core=false boundary=true surface=false in LayerSelector.
# core.select.residue_selector.LayerSelector: {0} Setting LayerSelector to use sidechain neighbors to determine burial.
# core.select.residue_selector.LayerSelector: {0} Set cutoffs for core and surface to 5.2 and 2, respectively, in LayerSelector.
# core.select.residue_selector.LayerSelector: {0} Setting LayerSelector to use sidechain neighbors to determine burial.
# core.select.residue_selector.LayerSelector: {0} Set cutoffs for core and surface to 5.2 and 2, respectively, in LayerSelector.
# core.select.residue_selector.LayerSelector: {0} Setting core=true boundary=false surface=false in LayerSelector.
# core.select.residue_selector.LayerSelector: {0} Setting LayerSelector to use sidechain neighbors to determine burial.
# core.select.residue_selector.LayerSelector: {0} Set cutoffs for core and surface to 5.2 and 2, respectively, in LayerSelector.
# core.select.residue_selector.PrimarySequenceNeighborhoodSelector: {0} Using residue selector entire_helix
# core.select.residue_selector.PrimarySequenceNeighborhoodSelector: {0} Using residue selector helix_cap
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "design" of type RestrictAbsentCanonicalAAS
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "pack" of type OperateOnResidueSubset
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "lock" of type OperateOnResidueSubset
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "layer_design" of type DesignRestrictions
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "prune" of type PruneBuriedUnsats
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "arochi" of type LimitAromaChi2
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "ex1_ex2" of type ExtraRotamersGeneric
# basic.io.database: {0} Database file opened: scoring/score_functions/P_AA_SS_cen6/P_AA_SS_cen6.txt
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined mover named "gen_profile" of type StructProfileMover
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined mover named "clear_constraints" of type ClearConstraintsMover
# core.pack.task.xml_util: {0} Object pack reading the following task_operations: Adding the following task operations
# arochi prune ex1_ex2 design pack lock layer_design
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined mover named "pack" of type PackRotamersMover
# protocols.rosetta_scripts.ParsedProtocol: {0} ParsedProtocol mover with the following settings
# protocols.rosetta_scripts.ParsedProtocol: {0} Added mover "gen_profile"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added mover "pack"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added mover "clear_constraints"
# core.scoring.ScoreFunctionFactory: {0} SCOREFUNCTION: beta_nov16.wts
# protocols.jd2.parser.ScoreFunctionLoader: {0} defined score function "sfxn" with weights "beta_nov16"
# protocols.jd2.parser.ScoreFunctionLoader: {0}  setting sfxn weight res_type_constraint to 1
# core.select.residue_selector.LayerSelector: {0} Setting LayerSelector to use sidechain neighbors to determine burial.
# core.select.residue_selector.LayerSelector: {0} Set cutoffs for core and surface to 5.2 and 2, respectively, in LayerSelector.
# core.select.residue_selector.LayerSelector: {0} Setting core=false boundary=false surface=true in LayerSelector.
# core.select.residue_selector.LayerSelector: {0} Setting LayerSelector to use sidechain neighbors to determine burial.
# core.select.residue_selector.LayerSelector: {0} Set cutoffs for core and surface to 5.2 and 2, respectively, in LayerSelector.
# core.select.residue_selector.LayerSelector: {0} Setting LayerSelector to use sidechain neighbors to determine burial.
# core.select.residue_selector.LayerSelector: {0} Set cutoffs for core and surface to 5.2 and 2, respectively, in LayerSelector.
# core.select.residue_selector.LayerSelector: {0} Setting core=false boundary=true surface=false in LayerSelector.
# core.select.residue_selector.LayerSelector: {0} Setting LayerSelector to use sidechain neighbors to determine burial.
# core.select.residue_selector.LayerSelector: {0} Set cutoffs for core and surface to 5.2 and 2, respectively, in LayerSelector.
# core.select.residue_selector.LayerSelector: {0} Setting LayerSelector to use sidechain neighbors to determine burial.
# core.select.residue_selector.LayerSelector: {0} Set cutoffs for core and surface to 5.2 and 2, respectively, in LayerSelector.
# core.select.residue_selector.LayerSelector: {0} Setting core=true boundary=false surface=false in LayerSelector.
# core.select.residue_selector.LayerSelector: {0} Setting LayerSelector to use sidechain neighbors to determine burial.
# core.select.residue_selector.LayerSelector: {0} Set cutoffs for core and surface to 5.2 and 2, respectively, in LayerSelector.
# core.select.residue_selector.PrimarySequenceNeighborhoodSelector: {0} Using residue selector entire_helix
# core.select.residue_selector.PrimarySequenceNeighborhoodSelector: {0} Using residue selector helix_cap
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "design" of type RestrictAbsentCanonicalAAS
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "pack" of type OperateOnResidueSubset
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "lock" of type OperateOnResidueSubset
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "layer_design" of type DesignRestrictions
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "prune" of type PruneBuriedUnsats
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "arochi" of type LimitAromaChi2
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "ex1_ex2" of type ExtraRotamersGeneric
# basic.io.database: {0} Database file opened: scoring/score_functions/P_AA_SS_cen6/P_AA_SS_cen6.txt
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined mover named "gen_profile" of type StructProfileMover
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined mover named "clear_constraints" of type ClearConstraintsMover
# core.pack.task.xml_util: {0} Object pack reading the following task_operations: Adding the following task operations
# arochi prune ex1_ex2 design pack lock layer_design
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined mover named "pack" of type PackRotamersMover
# protocols.rosetta_scripts.ParsedProtocol: {0} ParsedProtocol mover with the following settings
# protocols.rosetta_scripts.ParsedProtocol: {0} Added mover "gen_profile"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added mover "pack"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added mover "clear_constraints"
# protocols.rosetta_scripts.ParsedProtocol: {0} =======================BEGIN MOVER StructProfileMover - gen_profile=======================
# core.select.residue_selector.NeighborhoodResidueSelector: {0} [ WARNING ] ################ Cloning pose and building neighbor graph ################
# core.select.residue_selector.NeighborhoodResidueSelector: {0} [ WARNING ] Ensure that pose is either scored or has update_residue_neighbors() called
# core.select.residue_selector.NeighborhoodResidueSelector: {0} [ WARNING ] before using NeighborhoodResidueSelector for maximum performance!
# core.select.residue_selector.NeighborhoodResidueSelector: {0} [ WARNING ] ##########################################################################
# protocols.rosetta_scripts.ParsedProtocol: {0} =======================BEGIN MOVER PackRotamersMover - pack=======================
# core.select.residue_selector.SecondaryStructureSelector: {0} Using dssp for secondary structure: LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} []
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} Using dssp for secondary structure: LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} []
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} Using dssp for secondary structure: LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} []
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.PrimarySequenceNeighborhoodSelector: {0} ]
# core.select.residue_selector.PrimarySequenceNeighborhoodSelector: {0} ]
# core.select.residue_selector.SecondaryStructureSelector: {0} Using dssp for secondary structure: LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} []
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} Using dssp for secondary structure: LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} []
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} Using dssp for secondary structure: LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} []
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} Using dssp for secondary structure: LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} []
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.PrimarySequenceNeighborhoodSelector: {0} ]
# core.select.residue_selector.PrimarySequenceNeighborhoodSelector: {0} ]
# core.select.residue_selector.SecondaryStructureSelector: {0} Using dssp for secondary structure: LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} []
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} Using dssp for secondary structure: LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} []
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} Using dssp for secondary structure: LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} []
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} Using dssp for secondary structure: LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} []
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.PrimarySequenceNeighborhoodSelector: {0} ]
# core.select.residue_selector.SecondaryStructureSelector: {0} Using dssp for secondary structure: LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} []
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} Using dssp for secondary structure: LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} []
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} Using dssp for secondary structure: LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} []
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.PrimarySequenceNeighborhoodSelector: {0} ]
# core.select.residue_selector.PrimarySequenceNeighborhoodSelector: {0} ]
# core.select.residue_selector.SecondaryStructureSelector: {0} Using dssp for secondary structure: LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} []
# core.select.residue_selector.SecondaryStructureSelector: {0} LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# core.select.residue_selector.SecondaryStructureSelector: {0} Using dssp for secondary structure: LHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL
# ...
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -390.991  1.34904  1.34904  0.30745
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -385.81  1.34904  1.34904  0.31955
# protocols.relax.FastRelax: {0} CMD: min  -407.572  1.26152  1.26152  0.31955
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -407.572  1.26152  1.26152  0.31955
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -339.635  1.26152  1.26152  0.55
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 2900 rotamers at 168 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -341.724  1.26152  1.26152  0.55
# protocols.relax.FastRelax: {0} CMD: min  -368.035  1.2131  1.2131  0.55
# protocols.relax.FastRelax: {0} MRP: 0  -368.035  -368.035  1.2131  1.2131
# protocols.relax.FastRelax: {0} CMD: accept_to_best  -368.035  1.2131  1.2131  0.55
# protocols.relax.FastRelax: {0} CMD: endrepeat  -368.035  1.2131  1.2131  0.55
# protocols::checkpoint: {0} Deleting checkpoints of FastRelax
# protocols.normalmode.NormalModeRelaxMover: {0} Rmsd: initial vs relaxed: 1.2131
# protocols.normalmode.NormalModeRelaxMover: {0} Rmsd: extrapolated vs relaxed: -nan
# protocols.normalmode.NormalModeRelaxMover: {0} score: -401.585
# protocols.normalmode.NormalModeRelaxMover: {0} printing mode_scales
# protocols.normalmode.NormalModeRelaxMover: {0} [0.720032, -0.114734, -0.0424478]
# protocols.normalmode.NormalModeRelaxMover: {0} Normal mode for mode no 4  0.98587 -0.15709 -0.05812
# protocols.normalmode.NormalModeRelaxMover: {0} Solving Normal Mode for given pose...
# protocols.normalmode.NormalMode: {0} Solving Cartesian Normal Mode, Distance cut set as 10, using uniform spring constants:1
# protocols.normalmode.NormalMode: {0} Diagonalization done.
# protocols.normalmode.NormalModeRelaxMover: {0} NM solved in 0.163175 sec.
# protocols.normalmode.NormalModeRelaxMover: {0} CNM, Dynamic scale for set as 14.4, given moving distance 1.6
# protocols.relax.FastRelax: {0} CMD: repeat  -79.3599  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -79.3599  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -258.723  0  0  0.022
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 3429 rotamers at 168 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -314.221  0  0  0.022
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -308.357  0  0  0.02805
# protocols.relax.FastRelax: {0} CMD: min  -538.795  1.29028  1.29028  0.02805
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -538.795  1.29028  1.29028  0.02805
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -361.109  1.29028  1.29028  0.14575
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 3112 rotamers at 168 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -408.75  1.29028  1.29028  0.14575
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -399.812  1.29028  1.29028  0.154
# protocols.relax.FastRelax: {0} CMD: min  -463.666  1.29884  1.29884  0.154
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -463.666  1.29884  1.29884  0.154
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -390.978  1.29884  1.29884  0.30745
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 2963 rotamers at 168 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -397.735  1.29884  1.29884  0.30745
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -392.658  1.29884  1.29884  0.31955
# protocols.relax.FastRelax: {0} CMD: min  -415.17  1.23944  1.23944  0.31955
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -415.17  1.23944  1.23944  0.31955
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -348.236  1.23944  1.23944  0.55
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 2906 rotamers at 168 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -348.548  1.23944  1.23944  0.55
# protocols.relax.FastRelax: {0} CMD: min  -372.03  1.20241  1.20241  0.55
# protocols.relax.FastRelax: {0} MRP: 0  -372.03  -372.03  1.20241  1.20241
# protocols.relax.FastRelax: {0} CMD: accept_to_best  -372.03  1.20241  1.20241  0.55
# protocols.relax.FastRelax: {0} CMD: endrepeat  -372.03  1.20241  1.20241  0.55
# protocols::checkpoint: {0} Deleting checkpoints of FastRelax
# protocols.normalmode.NormalModeRelaxMover: {0} Rmsd: initial vs relaxed: 1.20241
# protocols.normalmode.NormalModeRelaxMover: {0} Rmsd: extrapolated vs relaxed: -nan
# protocols.normalmode.NormalModeRelaxMover: {0} score: -401.908
# protocols.normalmode.NormalModeRelaxMover: {0} printing mode_scales
# protocols.normalmode.NormalModeRelaxMover: {0} [0.927693, -0.933756, -0.00173906]
# protocols.normalmode.NormalModeRelaxMover: {0} Normal mode for mode no 5  0.70480 -0.70941 -0.00132
# protocols.normalmode.NormalModeRelaxMover: {0} Solving Normal Mode for given pose...
# protocols.normalmode.NormalMode: {0} Solving Cartesian Normal Mode, Distance cut set as 10, using uniform spring constants:1
# protocols.normalmode.NormalMode: {0} Diagonalization done.
# protocols.normalmode.NormalModeRelaxMover: {0} NM solved in 0.163286 sec.
# protocols.normalmode.NormalModeRelaxMover: {0} CNM, Dynamic scale for set as 14.4, given moving distance 1.6
# protocols.relax.FastRelax: {0} CMD: repeat  -79.3599  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -79.3599  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -258.723  0  0  0.022
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 3429 rotamers at 168 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -312.09  0  0  0.022
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -304.962  0  0  0.02805
# protocols.relax.FastRelax: {0} CMD: min  -521.867  1.18485  1.18485  0.02805
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -521.867  1.18485  1.18485  0.02805
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -367.02  1.18485  1.18485  0.14575
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 3148 rotamers at 168 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -405.111  1.18485  1.18485  0.14575
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -397.029  1.18485  1.18485  0.154
# protocols.relax.FastRelax: {0} CMD: min  -466.483  1.25265  1.25265  0.154
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -466.483  1.25265  1.25265  0.154
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -399.061  1.25265  1.25265  0.30745
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 2980 rotamers at 168 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -407.065  1.25265  1.25265  0.30745
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -402.268  1.25265  1.25265  0.31955
# protocols.relax.FastRelax: {0} CMD: min  -415.09  1.21895  1.21895  0.31955
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -415.09  1.21895  1.21895  0.31955
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -346.155  1.21895  1.21895  0.55
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 2922 rotamers at 168 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -346.354  1.21895  1.21895  0.55
# protocols.relax.FastRelax: {0} CMD: min  -371.746  1.19426  1.19426  0.55
# protocols.relax.FastRelax: {0} MRP: 0  -371.746  -371.746  1.19426  1.19426
# protocols.relax.FastRelax: {0} CMD: accept_to_best  -371.746  1.19426  1.19426  0.55
# protocols.relax.FastRelax: {0} CMD: endrepeat  -371.746  1.19426  1.19426  0.55
# protocols::checkpoint: {0} Deleting checkpoints of FastRelax
# protocols.normalmode.NormalModeRelaxMover: {0} Rmsd: initial vs relaxed: 1.19426
# protocols.normalmode.NormalModeRelaxMover: {0} Rmsd: extrapolated vs relaxed: 0.261268
# protocols.normalmode.NormalModeRelaxMover: {0} score: -403.627
# protocols.normalmode.NormalModeRelaxMover: {0} printing mode_scales
# protocols.normalmode.NormalModeRelaxMover: {0} [-0.142614, 0.755191, -0.794453]
# protocols.normalmode.NormalModeRelaxMover: {0} Normal mode for mode no 6 -0.12902  0.68321 -0.71873
# protocols.normalmode.NormalModeRelaxMover: {0} Solving Normal Mode for given pose...
# protocols.normalmode.NormalMode: {0} Solving Cartesian Normal Mode, Distance cut set as 10, using uniform spring constants:1
# protocols.normalmode.NormalMode: {0} Diagonalization done.
# protocols.normalmode.NormalModeRelaxMover: {0} NM solved in 0.163922 sec.
# protocols.normalmode.NormalModeRelaxMover: {0} CNM, Dynamic scale for set as 14.4, given moving distance 1.6
# protocols.relax.FastRelax: {0} CMD: repeat  -79.3599  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -79.3599  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -258.723  0  0  0.022
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 3429 rotamers at 168 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -313.396  0  0  0.022
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -306.322  0  0  0.02805
# protocols.relax.FastRelax: {0} CMD: min  -524.302  0.894226  0.894226  0.02805
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -524.302  0.894226  0.894226  0.02805
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -338.34  0.894226  0.894226  0.14575
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 3106 rotamers at 168 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -353.878  0.894226  0.894226  0.14575
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -342.193  0.894226  0.894226  0.154
# protocols.relax.FastRelax: {0} CMD: min  -433.32  0.794172  0.794172  0.154
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -433.32  0.794172  0.794172  0.154
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -354.259  0.794172  0.794172  0.30745
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 2953 rotamers at 168 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -359.802  0.794172  0.794172  0.30745
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -353.986  0.794172  0.794172  0.31955
# protocols.relax.FastRelax: {0} CMD: min  -386.981  0.806949  0.806949  0.31955
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -386.981  0.806949  0.806949  0.31955
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -318.836  0.806949  0.806949  0.55
# core.pack.task: {0} Packer task: initialize from command line()
# core.pack.pack_rotamers: {0} built 2917 rotamers at 168 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -319.701  0.806949  0.806949  0.55
# protocols.relax.FastRelax: {0} CMD: min  -348.661  0.917382  0.917382  0.55
# protocols.relax.FastRelax: {0} MRP: 0  -348.661  -348.661  0.917382  0.917382
# protocols.relax.FastRelax: {0} CMD: accept_to_best  -348.661  0.917382  0.917382  0.55
# protocols.relax.FastRelax: {0} CMD: endrepeat  -348.661  0.917382  0.917382  0.55
# protocols::checkpoint: {0} Deleting checkpoints of FastRelax
# protocols.normalmode.NormalModeRelaxMover: {0} Rmsd: initial vs relaxed: 0.917382
# protocols.normalmode.NormalModeRelaxMover: {0} Rmsd: extrapolated vs relaxed: 0.300907
# protocols.normalmode.NormalModeRelaxMover: {0} score: -391.908
# protocols.normalmode.NormalModeRelaxMover: {0} final pose with score -401.908
# protocols.rosetta_scripts.ParsedProtocol: {0} setting status to success
# ((95, 'CYS', (60.0,)), (59, 'CYS', (-30.0,)))
# core.scoring.ScoreFunctionFactory: {0} SCOREFUNCTION: beta_nov16.wts

# %%
stapled
# Out:
# [{<pyrosetta.distributed.packed_pose.core.PackedPose at 0x7fff60491950>,
#   <pyrosetta.distributed.packed_pose.core.PackedPose at 0x7fff612ff5d0>,
#   <pyrosetta.distributed.packed_pose.core.PackedPose at 0x7fff953795d0>},
#  {<pyrosetta.distributed.packed_pose.core.PackedPose at 0x7fff6fa35f90>},
#  {<pyrosetta.distributed.packed_pose.core.PackedPose at 0x7fff6f8993d0>,
#   <pyrosetta.distributed.packed_pose.core.PackedPose at 0x7fff954a0c90>,
#   <pyrosetta.distributed.packed_pose.core.PackedPose at 0x7fff954d9390>},
#  {}]

# %%
stapled_flat = [item for sublist in stapled for item in sublist]
for i, ppose in enumerate(stapled_flat):
    ppose.pose.dump_pdb("pst{i}.pdb".format(i=i))

# %%
sts = []
for i, st in enumerate(stapled_flat):
    print(st.pose.scores)
    if i > 3: 
        break
    st = check_disulf_energy(st)
    st = relax(st)
    sts.append(st)
    st.pose.dump_pdb("r{i}.pdb".format(i=i))
# Out:
# {'abego_str': 'XAAAAAAAAAAAAAAAAAAAAAGBBAAAAAAAAAAAAAAAAAAAAAAGBABAAAAAAAAAAAAAAAAAAAAAGBBAAAAAAAAAAAAAAAAAAAABBBBBBGAAAAAAAAAAAAAAAAAAAAGBBAAAAAAAAAAAAAAAAAAAAAAGBABAAAAAAAAAAAAAAAAAAAAAGBBAAAAAAAAAAAAAAAAAAAAAAGBX', 'closure_type': 'strict_remodel', 'disulfide_at': '89,108', 'dssp': 'LHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLLHHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHLLLLLLLHHHHHHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHHHHHHHHHLLLLLHHHHHHHHHHHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHLLLL', 'new_loop_resis': '93,97,98,99,100,101', 'parent': 'hDHR10_5CWG', 'scaffold': 'DHR', 'sfxn_used': 'beta_nov16', 'bb_clash': 57.72700119018555, 'ddg': -91.8280029296875, 'dslf_fa13': 9.460720398889455, 'fa_atr': -1212.7718630591628, 'fa_dun_dev': 29.523900330160266, 'fa_dun_rot': 158.94283828877704, 'fa_dun_semi': 221.01380987746106, 'fa_elec': -417.0385216491647, 'fa_intra_atr_xover4': -73.86658456302659, 'fa_intra_elec': -51.76752789233086, 'fa_intra_rep_xover4': 66.9274776011832, 'fa_intra_sol_xover4': 51.334381521185215, 'fa_rep': 343.77934277394263, 'fa_sol': 955.1392428491444, 'hbond_bb_sc': -10.30316157118294, 'hbond_lr_bb': -8.108210843618574, 'hbond_sc': -35.90397642080348, 'hbond_sr_bb': -165.6735551455376, 'hxl_tors': 16.342998976333728, 'interface_buried_sasa': 2097.6640625, 'lk_ball': 579.5156099614248, 'lk_ball_bridge': 3.150080080125278, 'lk_ball_bridge_uncpl': 25.468639540037586, 'lk_ball_iso': 1414.4883944592168, 'omega': 32.65121430347892, 'p_aa_pp': -65.20504635573222, 'parent_length': 200.0, 'pivot_helix': 4.0, 'pre_break_helix': 4.0, 'pro_close': 0.0, 'rama_prepro': 49.00016687930914, 'ref': -11.141276000000001, 'sc': 0.7210000157356262, 'sc_int': 0.7950000166893005, 'score': 0.0, 'score_A': -123.61299896240234, 'score_B': -140.5570068359375, 'score_per_res': -2.7980000972747803, 'shift': -1.0, 'total_length': 200.0, 'total_score': -425.8824002378498}
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Validating input script...
# protocols.rosetta_scripts.RosettaScriptsParser: {0} ...done
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Parsed script:
# <ROSETTASCRIPTS>
# 	<SCOREFXNS>
# 		<ScoreFunction name="sfxn_cart" weights="ref2015_cart"/>
# 		<ScoreFunction name="sfxn" weights="ref2015"/>
# 	</SCOREFXNS>
# 	<RESIDUE_SELECTORS>
# 		<True name="all"/>
# 		<SSElement chain="A" name="design" reassign_short_terminal_loop="2" selection="3,H,S" to_selection="-3,H,E"/>
# 		<Not name="not_design" selector="design"/>
# 		<Neighborhood distance="8.0" include_focus_in_subset="0" name="pack" selector="design"/>
# 		<Not name="not_pack" selector="pack"/>
# 		<And name="lock_selector" selectors="not_pack,not_design"/>
# 	</RESIDUE_SELECTORS>
# 	<TASKOPERATIONS>
# 		<PruneBuriedUnsats allow_even_trades="false" atomic_depth_cutoff="3.5" minimum_hbond_energy="-1.0" name="prune"/>
# 		<LimitAromaChi2 chi2max="110" chi2min="70" include_trp="True" name="arochi"/>
# 		<ExtraRotamersGeneric ex1="1" ex2="1" name="ex1_ex2"/>
# 		<OperateOnResidueSubset name="lock" selector="lock_selector">
# 			<PreventRepackingRLT/>
# 		</OperateOnResidueSubset>
# 	</TASKOPERATIONS>
# 	<FILTERS>
# 		<Rmsd by_aln="0" chains="A" confidence="0" name="rmsd_cart" reference_name="before_relax" superimpose="0" threshold="5"/>
# 	</FILTERS>
# 	<MOVERS>
# 		<SavePoseMover name="save_before_relax" reference_name="before_relax" restore_pose="0"/>
# 		<FastRelax bondangle="true" bondlength="true" cartesian="true" name="relax" relaxscript="MonomerRelax2019" repeats="2" scorefxn="sfxn_cart" task_operations="arochi,prune,ex1_ex2,lock">
# 			<MoveMap bb="false" chi="false" jump="false" name="mm">
# 				<ResidueSelector bb="false" bondangle="false" bondlength="false" chi="false" selector="all"/>
# 				<ResidueSelector bb="false" bondangle="true" bondlength="true" chi="true" selector="pack"/>
# 				<ResidueSelector bb="true" bondangle="true" bondlength="true" chi="true" selector="design"/>
# 			</MoveMap>
# 		</FastRelax>
# 	</MOVERS>
# 	<PROTOCOLS>
# 		<Add mover="save_before_relax"/>
# 		<Add mover="relax"/>
# 		<Add filter="rmsd_cart"/>
# 	</PROTOCOLS>
# 	<OUTPUT scorefxn="sfxn"/>
# </ROSETTASCRIPTS>
# core.scoring.ScoreFunctionFactory: {0} SCOREFUNCTION: beta_nov16.wts
# protocols.jd2.parser.ScoreFunctionLoader: {0} defined score function "sfxn_cart" with weights "ref2015_cart"
# protocols.jd2.parser.ScoreFunctionLoader: {0} defined score function "sfxn" with weights "ref2015"
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "prune" of type PruneBuriedUnsats
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "arochi" of type LimitAromaChi2
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "ex1_ex2" of type ExtraRotamersGeneric
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "lock" of type OperateOnResidueSubset
# core.pose.ref_pose: {0} Loading PDB: before_relax
# protocols.protein_interface_design.filters.RmsdFilter: {0} RMSD filter with superimpose=0 and threshold=5
# protocols.protein_interface_design.filters.RmsdFilter: {0} selected residues
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined filter named "rmsd_cart" of type Rmsd
# core.pose.ref_pose: {0} Loading PDB: before_relax
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined mover named "save_before_relax" of type SavePoseMover
# core.scoring.ScoreFunctionFactory: {0} SCOREFUNCTION: beta_nov16.wts
# core.pack.task.xml_util: {0} Object relax reading the following task_operations: Adding the following task operations
# arochi prune ex1_ex2 lock
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined mover named "relax" of type FastRelax
# protocols.rosetta_scripts.ParsedProtocol: {0} ParsedProtocol mover with the following settings
# protocols.rosetta_scripts.ParsedProtocol: {0} Added mover "save_before_relax"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added mover "relax"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added filter "rmsd_cart"
# core.scoring.ScoreFunctionFactory: {0} SCOREFUNCTION: beta_nov16.wts
# protocols.jd2.parser.ScoreFunctionLoader: {0} defined score function "sfxn_cart" with weights "ref2015_cart"
# protocols.jd2.parser.ScoreFunctionLoader: {0} defined score function "sfxn" with weights "ref2015"
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "prune" of type PruneBuriedUnsats
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "arochi" of type LimitAromaChi2
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "ex1_ex2" of type ExtraRotamersGeneric
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "lock" of type OperateOnResidueSubset
# core.pose.ref_pose: {0} Loading PDB: before_relax
# protocols.protein_interface_design.filters.RmsdFilter: {0} RMSD filter with superimpose=0 and threshold=5
# protocols.protein_interface_design.filters.RmsdFilter: {0} selected residues
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined filter named "rmsd_cart" of type Rmsd
# core.pose.ref_pose: {0} Loading PDB: before_relax
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined mover named "save_before_relax" of type SavePoseMover
# core.scoring.ScoreFunctionFactory: {0} SCOREFUNCTION: beta_nov16.wts
# core.pack.task.xml_util: {0} Object relax reading the following task_operations: Adding the following task operations
# arochi prune ex1_ex2 lock
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined mover named "relax" of type FastRelax
# protocols.rosetta_scripts.ParsedProtocol: {0} ParsedProtocol mover with the following settings
# protocols.rosetta_scripts.ParsedProtocol: {0} Added mover "save_before_relax"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added mover "relax"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added filter "rmsd_cart"
# protocols.rosetta_scripts.ParsedProtocol: {0} =======================BEGIN MOVER SavePoseMover - save_before_relax=======================
# protocols.rosetta_scripts.ParsedProtocol: {0} =======================BEGIN MOVER FastRelax - relax=======================
# core.energy_methods.CartesianBondedEnergy: {0} Creating new peptide-bonded energy container (200)
# protocols.relax.FastRelax: {0} CMD: repeat  -315.998  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -315.998  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -497.514  0  0  0.022
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Building hbond graph
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Hbond graph has: 13910 edges requiring: 6131616 bytes
# core.chemical.AtomICoor: {0} [ WARNING ] IcoorAtomID::atom_id(): Cannot get atom_id for POLYMER_LOWER of residue LEU 1.  Returning BOGUS ID instead.
# core.conformation.Residue: {0} [ WARNING ] missing an atom: 1  H   that depends on a nonexistent polymer connection!
# core.conformation.Residue: {0} [ WARNING ]  --> generating it using idealized coordinates.
# core.scoring.atomic_depth.AtomicDepth: {0} actual boxlength 130, box[117*110*130], resolution  0.504
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Pruned 1040 / 10789 rotamers.
# core.pack.pack_rotamers: {0} built 9749 rotamers at 162 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -541.251  0  0  0.022
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -535.701  0  0  0.02805
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 89 BRANCH 1
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 108 BRANCH 1
# protocols.relax.FastRelax: {0} CMD: min  -723.725  0.718297  0.718297  0.02805
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -723.725  0.718297  0.718297  0.02805
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -492.284  0.718297  0.718297  0.14575
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Building hbond graph
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Hbond graph has: 13489 edges requiring: 5836256 bytes
# core.chemical.AtomICoor: {0} [ WARNING ] IcoorAtomID::atom_id(): Cannot get atom_id for POLYMER_LOWER of residue LEU 1.  Returning BOGUS ID instead.
# core.conformation.Residue: {0} [ WARNING ] missing an atom: 1  H   that depends on a nonexistent polymer connection!
# core.conformation.Residue: {0} [ WARNING ]  --> generating it using idealized coordinates.
# core.scoring.atomic_depth.AtomicDepth: {0} actual boxlength 129, box[116*108*129], resolution  0.504
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Pruned 657 / 9994 rotamers.
# core.pack.pack_rotamers: {0} built 9337 rotamers at 163 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -507.675  0.718297  0.718297  0.14575
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -495.921  0.718297  0.718297  0.154
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 89 BRANCH 1
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 108 BRANCH 1
# protocols.relax.FastRelax: {0} CMD: min  -619.916  0.606416  0.606416  0.154
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -619.916  0.606416  0.606416  0.154
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -547.099  0.606416  0.606416  0.30745
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Building hbond graph
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Hbond graph has: 12949 edges requiring: 5539456 bytes
# core.chemical.AtomICoor: {0} [ WARNING ] IcoorAtomID::atom_id(): Cannot get atom_id for POLYMER_LOWER of residue LEU 1.  Returning BOGUS ID instead.
# core.conformation.Residue: {0} [ WARNING ] missing an atom: 1  H   that depends on a nonexistent polymer connection!
# core.conformation.Residue: {0} [ WARNING ]  --> generating it using idealized coordinates.
# core.scoring.atomic_depth.AtomicDepth: {0} actual boxlength 129, box[116*108*129], resolution  0.504
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Pruned 707 / 9401 rotamers.
# core.pack.pack_rotamers: {0} built 8694 rotamers at 162 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -543.695  0.606416  0.606416  0.30745
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -537.978  0.606416  0.606416  0.31955
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 89 BRANCH 1
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 108 BRANCH 1
# protocols.relax.FastRelax: {0} CMD: min  -564.306  0.535505  0.535505  0.31955
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -564.306  0.535505  0.535505  0.31955
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -498.286  0.535505  0.535505  0.55
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Building hbond graph
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Hbond graph has: 12578 edges requiring: 5107272 bytes
# core.chemical.AtomICoor: {0} [ WARNING ] IcoorAtomID::atom_id(): Cannot get atom_id for POLYMER_LOWER of residue LEU 1.  Returning BOGUS ID instead.
# core.conformation.Residue: {0} [ WARNING ] missing an atom: 1  H   that depends on a nonexistent polymer connection!
# core.conformation.Residue: {0} [ WARNING ]  --> generating it using idealized coordinates.
# core.scoring.atomic_depth.AtomicDepth: {0} actual boxlength 129, box[117*108*129], resolution  0.504
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Pruned 718 / 8415 rotamers.
# core.pack.pack_rotamers: {0} built 7697 rotamers at 161 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -496.592  0.535505  0.535505  0.55
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 89 BRANCH 1
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 108 BRANCH 1
# protocols.relax.FastRelax: {0} CMD: min  -510.138  0.507956  0.507956  0.55
# protocols.relax.FastRelax: {0} MRP: 0  -510.138  -510.138  0.507956  0.507956
# protocols.relax.FastRelax: {0} CMD: accept_to_best  -510.138  0.507956  0.507956  0.55
# protocols.relax.FastRelax: {0} CMD: endrepeat  -510.138  0.507956  0.507956  0.55
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -510.138  0.507956  0.507956  0.55
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -620.858  0.507956  0.507956  0.022
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Building hbond graph
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Hbond graph has: 14812 edges requiring: 6195488 bytes
# core.chemical.AtomICoor: {0} [ WARNING ] IcoorAtomID::atom_id(): Cannot get atom_id for POLYMER_LOWER of residue LEU 1.  Returning BOGUS ID instead.
# core.conformation.Residue: {0} [ WARNING ] missing an atom: 1  H   that depends on a nonexistent polymer connection!
# core.conformation.Residue: {0} [ WARNING ]  --> generating it using idealized coordinates.
# core.scoring.atomic_depth.AtomicDepth: {0} actual boxlength 129, box[117*109*129], resolution  0.504
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Pruned 1088 / 10696 rotamers.
# core.pack.pack_rotamers: {0} built 9608 rotamers at 161 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -638.577  0.507956  0.507956  0.022
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -633.744  0.507956  0.507956  0.02805
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 89 BRANCH 1
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 108 BRANCH 1
# protocols.relax.FastRelax: {0} CMD: min  -735.984  0.853082  0.853082  0.02805
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -735.984  0.853082  0.853082  0.02805
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -504.646  0.853082  0.853082  0.14575
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Building hbond graph
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Hbond graph has: 15133 edges requiring: 6537328 bytes
# core.chemical.AtomICoor: {0} [ WARNING ] IcoorAtomID::atom_id(): Cannot get atom_id for POLYMER_LOWER of residue LEU 1.  Returning BOGUS ID instead.
# core.conformation.Residue: {0} [ WARNING ] missing an atom: 1  H   that depends on a nonexistent polymer connection!
# core.conformation.Residue: {0} [ WARNING ]  --> generating it using idealized coordinates.
# core.scoring.atomic_depth.AtomicDepth: {0} actual boxlength 128, box[116*106*128], resolution  0.504
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Pruned 760 / 11239 rotamers.
# core.pack.pack_rotamers: {0} built 10479 rotamers at 163 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -510.068  0.853082  0.853082  0.14575
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -496.136  0.853082  0.853082  0.154
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 89 BRANCH 1
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 108 BRANCH 1
# protocols.relax.FastRelax: {0} CMD: min  -628.227  0.703972  0.703972  0.154
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -628.227  0.703972  0.703972  0.154
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -553.551  0.703972  0.703972  0.30745
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Building hbond graph
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Hbond graph has: 13240 edges requiring: 5638032 bytes
# core.chemical.AtomICoor: {0} [ WARNING ] IcoorAtomID::atom_id(): Cannot get atom_id for POLYMER_LOWER of residue LEU 1.  Returning BOGUS ID instead.
# core.conformation.Residue: {0} [ WARNING ] missing an atom: 1  H   that depends on a nonexistent polymer connection!
# core.conformation.Residue: {0} [ WARNING ]  --> generating it using idealized coordinates.
# core.scoring.atomic_depth.AtomicDepth: {0} actual boxlength 128, box[116*108*128], resolution  0.504
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Pruned 670 / 9584 rotamers.
# core.pack.pack_rotamers: {0} built 8914 rotamers at 162 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -551.78  0.703972  0.703972  0.30745
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -545.936  0.703972  0.703972  0.31955
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 89 BRANCH 1
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 108 BRANCH 1
# protocols.relax.FastRelax: {0} CMD: min  -569.276  0.634515  0.634515  0.31955
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -569.276  0.634515  0.634515  0.31955
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -500.851  0.634515  0.634515  0.55
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Building hbond graph
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Hbond graph has: 12997 edges requiring: 5276928 bytes
# core.chemical.AtomICoor: {0} [ WARNING ] IcoorAtomID::atom_id(): Cannot get atom_id for POLYMER_LOWER of residue LEU 1.  Returning BOGUS ID instead.
# core.conformation.Residue: {0} [ WARNING ] missing an atom: 1  H   that depends on a nonexistent polymer connection!
# core.conformation.Residue: {0} [ WARNING ]  --> generating it using idealized coordinates.
# core.scoring.atomic_depth.AtomicDepth: {0} actual boxlength 128, box[116*108*128], resolution  0.504
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Pruned 709 / 8773 rotamers.
# core.pack.pack_rotamers: {0} built 8064 rotamers at 161 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -497.35  0.634515  0.634515  0.55
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 89 BRANCH 1
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 108 BRANCH 1
# protocols.relax.FastRelax: {0} CMD: min  -512.537  0.583681  0.583681  0.55
# protocols.relax.FastRelax: {0} MRP: 1  -512.537  -512.537  0.583681  0.583681
# protocols.relax.FastRelax: {0} CMD: accept_to_best  -512.537  0.583681  0.583681  0.55
# protocols.relax.FastRelax: {0} CMD: endrepeat  -512.537  0.583681  0.583681  0.55
# protocols::checkpoint: {0} Deleting checkpoints of FastRelax
# protocols.rosetta_scripts.ParsedProtocol: {0} =======================BEGIN FILTER rmsd_cart=======================
# protocols.rosetta_scripts.ParsedProtocol: {0} =======================END FILTER rmsd_cart=======================
# protocols.rosetta_scripts.ParsedProtocol: {0} setting status to success
# protocols.rosetta_scripts.ParsedProtocol.REPORT: {0} ============Begin report for rmsd_cart==================
# protocols.rosetta_scripts.ParsedProtocol.REPORT: {0} RMSD: 0.601134
# ============End report for rmsd_cart==================
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Validating input script...
# protocols.rosetta_scripts.RosettaScriptsParser: {0} ...done
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Parsed script:
# <ROSETTASCRIPTS>
# 	<SCOREFXNS>
# 		<ScoreFunction name="sfxn" weights="beta_nov16"/>
# 		<ScoreFunction name="sfxn_cart" weights="beta_nov16_cart"/>
# 	</SCOREFXNS>
# 	<RESIDUE_SELECTORS>
# 		<True name="all"/>
# 		<ResidueName name="CYS" residue_name3="CYS,CYD"/>
# 		<Not name="not_CYS" selector="CYS"/>
# 		<Index name="new_loop_resis" resnums="93,97,98,99,100,101"/>
# 		<Neighborhood distance="8.0" name="around_new_loop" selector="new_loop_resis"/>
# 		<SSElement chain="A" name="design" reassign_short_terminal_loop="2" selection="3,H,S" to_selection="-3,H,E"/>
# 		<Not name="not_design" selector="design"/>
# 		<Neighborhood distance="8.0" include_focus_in_subset="0" name="pack" selector="design"/>
# 		<Not name="not_pack" selector="pack"/>
# 		<And name="lock_selector" selectors="not_pack,not_design"/>
# 	</RESIDUE_SELECTORS>
# 	<TASKOPERATIONS>
# 		<PruneBuriedUnsats allow_even_trades="false" atomic_depth_cutoff="3.5" minimum_hbond_energy="-1.0" name="prune"/>
# 		<LimitAromaChi2 chi2max="110" chi2min="70" include_trp="True" name="arochi"/>
# 		<ExtraRotamersGeneric ex1="1" ex2="1" name="ex1_ex2"/>
# 		<OperateOnResidueSubset name="lock" selector="lock_selector">
# 			<PreventRepackingRLT/>
# 		</OperateOnResidueSubset>
# 	</TASKOPERATIONS>
# 	<FILTERS>
# 		<Geometry confidence="0" count_bad_residues="true" name="geometry"/>
# 		<Geometry confidence="0" count_bad_residues="true" name="geometry_loop" residue_selector="around_new_loop"/>
# 		<Rmsd by_aln="0" chains="A" confidence="0" name="rmsd_dual" reference_name="before_relax" superimpose="0" threshold="5"/>
# 		<worst9mer confidence="0" name="9mer" rmsd_lookup_threshold="0.4"/>
# 	</FILTERS>
# 	<MOVERS>
# 		<SavePoseMover name="save_before_relax" reference_name="before_relax" restore_pose="0"/>
# 		<FastRelax bondangle="true" bondlength="true" dualspace="true" name="relax" relaxscript="MonomerRelax2019" repeats="2" scorefxn="sfxn_cart" task_operations="arochi,prune,ex1_ex2,lock">
# 			<MoveMap bb="false" chi="false" jump="false" name="mm">
# 				<ResidueSelector bb="false" bondangle="false" bondlength="false" chi="false" selector="all"/>
# 				<ResidueSelector bb="false" bondangle="false" bondlength="false" chi="true" selector="pack"/>
# 				<ResidueSelector bb="true" bondangle="false" bondlength="false" chi="true" selector="design"/>
# 				<ResidueSelector bb="true" bondangle="true" bondlength="true" chi="true" selector="CYS"/>
# 			</MoveMap>
# 		</FastRelax>
# 	</MOVERS>
# 	<PROTOCOLS>
# 		<Add mover="save_before_relax"/>
# 		<Add mover="relax"/>
# 		<Add filter="geometry"/>
# 		<Add filter="geometry_loop"/>
# 		<Add filter="rmsd_dual"/>
# 		<Add filter="9mer"/>
# 	</PROTOCOLS>
# 	<OUTPUT scorefxn="sfxn"/>
# </ROSETTASCRIPTS>
# core.scoring.ScoreFunctionFactory: {0} SCOREFUNCTION: beta_nov16.wts
# protocols.jd2.parser.ScoreFunctionLoader: {0} defined score function "sfxn" with weights "beta_nov16"
# protocols.jd2.parser.ScoreFunctionLoader: {0} defined score function "sfxn_cart" with weights "beta_nov16_cart"
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "prune" of type PruneBuriedUnsats
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "arochi" of type LimitAromaChi2
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "ex1_ex2" of type ExtraRotamersGeneric
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "lock" of type OperateOnResidueSubset
# core.select.residue_selector.util: {0} [ WARNING ] Selector name is empty!
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined filter named "geometry" of type Geometry
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined filter named "geometry_loop" of type Geometry
# core.pose.ref_pose: {0} Loading PDB: before_relax
# protocols.protein_interface_design.filters.RmsdFilter: {0} RMSD filter with superimpose=0 and threshold=5
# protocols.protein_interface_design.filters.RmsdFilter: {0} selected residues
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined filter named "rmsd_dual" of type Rmsd
# protocols.filters.LeastNativeLike9merFilter: {0} Structures which has the best fragment RMSD at the worst position greater than 99 will be filtered.
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined filter named "9mer" of type worst9mer
# core.pose.ref_pose: {0} Loading PDB: before_relax
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined mover named "save_before_relax" of type SavePoseMover
# core.scoring.ScoreFunctionFactory: {0} SCOREFUNCTION: beta_nov16.wts
# core.pack.task.xml_util: {0} Object relax reading the following task_operations: Adding the following task operations
# arochi prune ex1_ex2 lock
# protocols.relax.RelaxScriptManager: {0} Looking for MonomerRelax2019.dualspace.txt
# protocols.relax.RelaxScriptManager: {0} ================== Reading script file: /home/pleung/.conda/envs/cereal/lib/python3.7/site-packages/pyrosetta/database/sampling/relax_scripts/MonomerRelax2019.dualspace.txt ==================
# protocols.relax.RelaxScriptManager: {0} switch:torsion
# protocols.relax.RelaxScriptManager: {0} repeat %%nrepeats%%
# protocols.relax.RelaxScriptManager: {0} coord_cst_weight 1.0
# protocols.relax.RelaxScriptManager: {0} scale:fa_rep 0.040
# protocols.relax.RelaxScriptManager: {0} repack
# protocols.relax.RelaxScriptManager: {0} scale:fa_rep 0.051
# protocols.relax.RelaxScriptManager: {0} min 0.01
# protocols.relax.RelaxScriptManager: {0} coord_cst_weight 0.5
# protocols.relax.RelaxScriptManager: {0} scale:fa_rep 0.265
# protocols.relax.RelaxScriptManager: {0} repack
# protocols.relax.RelaxScriptManager: {0} scale:fa_rep 0.280
# protocols.relax.RelaxScriptManager: {0} min 0.01
# protocols.relax.RelaxScriptManager: {0} coord_cst_weight 0.0
# protocols.relax.RelaxScriptManager: {0} scale:fa_rep 0.559
# protocols.relax.RelaxScriptManager: {0} repack
# protocols.relax.RelaxScriptManager: {0} scale:fa_rep 0.581
# protocols.relax.RelaxScriptManager: {0} min 0.01
# protocols.relax.RelaxScriptManager: {0} coord_cst_weight 0.0
# protocols.relax.RelaxScriptManager: {0} scale:fa_rep 1
# protocols.relax.RelaxScriptManager: {0} repack
# protocols.relax.RelaxScriptManager: {0} min 0.00001
# protocols.relax.RelaxScriptManager: {0} accept_to_best
# protocols.relax.RelaxScriptManager: {0} endrepeat
# protocols.relax.RelaxScriptManager: {0}
# protocols.relax.RelaxScriptManager: {0} switch:cartesian
# protocols.relax.RelaxScriptManager: {0} repeat 1
# protocols.relax.RelaxScriptManager: {0} coord_cst_weight 1.0
# protocols.relax.RelaxScriptManager: {0} scale:fa_rep 0.040
# protocols.relax.RelaxScriptManager: {0} repack
# protocols.relax.RelaxScriptManager: {0} scale:fa_rep 0.051
# protocols.relax.RelaxScriptManager: {0} min 0.01
# protocols.relax.RelaxScriptManager: {0} coord_cst_weight 0.5
# protocols.relax.RelaxScriptManager: {0} scale:fa_rep 0.265
# protocols.relax.RelaxScriptManager: {0} repack
# protocols.relax.RelaxScriptManager: {0} scale:fa_rep 0.280
# protocols.relax.RelaxScriptManager: {0} min 0.01
# protocols.relax.RelaxScriptManager: {0} coord_cst_weight 0.0
# protocols.relax.RelaxScriptManager: {0} scale:fa_rep 0.559
# protocols.relax.RelaxScriptManager: {0} repack
# protocols.relax.RelaxScriptManager: {0} scale:fa_rep 0.581
# protocols.relax.RelaxScriptManager: {0} min 0.01
# protocols.relax.RelaxScriptManager: {0} coord_cst_weight 0.0
# protocols.relax.RelaxScriptManager: {0} scale:fa_rep 1
# protocols.relax.RelaxScriptManager: {0} repack
# protocols.relax.RelaxScriptManager: {0} min 0.00001
# protocols.relax.RelaxScriptManager: {0} accept_to_best
# protocols.relax.RelaxScriptManager: {0} endrepeat
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined mover named "relax" of type FastRelax
# protocols.rosetta_scripts.ParsedProtocol: {0} ParsedProtocol mover with the following settings
# protocols.rosetta_scripts.ParsedProtocol: {0} Added mover "save_before_relax"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added mover "relax"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added filter "geometry"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added filter "geometry_loop"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added filter "rmsd_dual"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added filter "9mer"
# core.scoring.ScoreFunctionFactory: {0} SCOREFUNCTION: beta_nov16.wts
# protocols.jd2.parser.ScoreFunctionLoader: {0} defined score function "sfxn" with weights "beta_nov16"
# protocols.jd2.parser.ScoreFunctionLoader: {0} defined score function "sfxn_cart" with weights "beta_nov16_cart"
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "prune" of type PruneBuriedUnsats
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "arochi" of type LimitAromaChi2
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "ex1_ex2" of type ExtraRotamersGeneric
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "lock" of type OperateOnResidueSubset
# core.select.residue_selector.util: {0} [ WARNING ] Selector name is empty!
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined filter named "geometry" of type Geometry
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined filter named "geometry_loop" of type Geometry
# core.pose.ref_pose: {0} Loading PDB: before_relax
# protocols.protein_interface_design.filters.RmsdFilter: {0} RMSD filter with superimpose=0 and threshold=5
# protocols.protein_interface_design.filters.RmsdFilter: {0} selected residues
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined filter named "rmsd_dual" of type Rmsd
# protocols.filters.LeastNativeLike9merFilter: {0} Structures which has the best fragment RMSD at the worst position greater than 99 will be filtered.
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined filter named "9mer" of type worst9mer
# core.pose.ref_pose: {0} Loading PDB: before_relax
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined mover named "save_before_relax" of type SavePoseMover
# core.scoring.ScoreFunctionFactory: {0} SCOREFUNCTION: beta_nov16.wts
# core.pack.task.xml_util: {0} Object relax reading the following task_operations: Adding the following task operations
# arochi prune ex1_ex2 lock
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined mover named "relax" of type FastRelax
# protocols.rosetta_scripts.ParsedProtocol: {0} ParsedProtocol mover with the following settings
# protocols.rosetta_scripts.ParsedProtocol: {0} Added mover "save_before_relax"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added mover "relax"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added filter "geometry"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added filter "geometry_loop"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added filter "rmsd_dual"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added filter "9mer"
# protocols.rosetta_scripts.ParsedProtocol: {0} =======================BEGIN MOVER SavePoseMover - save_before_relax=======================
# protocols.rosetta_scripts.ParsedProtocol: {0} =======================BEGIN MOVER FastRelax - relax=======================
# core.chemical.GlobalResidueTypeSet: {0} Loading (but possibly not actually using) 'CYD' from the PDB components dictionary for residue type 'pdb_CYD'
# core.energy_methods.CartesianBondedEnergy: {0} Creating new peptide-bonded energy container (200)
# protocols.relax.FastRelax: {0} Using AtomTreeMinimizer
# protocols.relax.FastRelax: {0} CMD: switch:torsion  -407.872  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: repeat  -407.872  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -407.872  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -589.388  0  0  0.022
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Building hbond graph
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Hbond graph has: 13910 edges requiring: 6131616 bytes
# core.chemical.AtomICoor: {0} [ WARNING ] IcoorAtomID::atom_id(): Cannot get atom_id for POLYMER_LOWER of residue LEU 1.  Returning BOGUS ID instead.
# core.conformation.Residue: {0} [ WARNING ] missing an atom: 1  H   that depends on a nonexistent polymer connection!
# core.conformation.Residue: {0} [ WARNING ]  --> generating it using idealized coordinates.
# core.scoring.atomic_depth.AtomicDepth: {0} actual boxlength 130, box[117*110*130], resolution  0.504
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Pruned 1040 / 10789 rotamers.
# core.pack.pack_rotamers: {0} built 9749 rotamers at 162 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -624.481  0  0  0.022
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -619.602  0  0  0.02805
# protocols.relax.FastRelax: {0} CMD: min  -907.463  1.49331  1.49331  0.02805
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -907.463  1.49331  1.49331  0.02805
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -521.812  1.49331  1.49331  0.14575
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Building hbond graph
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Hbond graph has: 14179 edges requiring: 6573432 bytes
# core.chemical.AtomICoor: {0} [ WARNING ] IcoorAtomID::atom_id(): Cannot get atom_id for POLYMER_LOWER of residue LEU 1.  Returning BOGUS ID instead.
# core.conformation.Residue: {0} [ WARNING ] missing an atom: 1  H   that depends on a nonexistent polymer connection!
# core.conformation.Residue: {0} [ WARNING ]  --> generating it using idealized coordinates.
# core.scoring.atomic_depth.AtomicDepth: {0} actual boxlength 123, box[111*106*123], resolution  0.504
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Pruned 581 / 11587 rotamers.
# core.pack.pack_rotamers: {0} built 11006 rotamers at 170 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -540.828  1.49331  1.49331  0.14575
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -517.218  1.49331  1.49331  0.154
# protocols.relax.FastRelax: {0} CMD: min  -754.365  1.13573  1.13573  0.154
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -754.365  1.13573  1.13573  0.154
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -655.262  1.13573  1.13573  0.30745
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Building hbond graph
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Hbond graph has: 11516 edges requiring: 5214728 bytes
# core.chemical.AtomICoor: {0} [ WARNING ] IcoorAtomID::atom_id(): Cannot get atom_id for POLYMER_LOWER of residue LEU 1.  Returning BOGUS ID instead.
# core.conformation.Residue: {0} [ WARNING ] missing an atom: 1  H   that depends on a nonexistent polymer connection!
# core.conformation.Residue: {0} [ WARNING ]  --> generating it using idealized coordinates.
# core.scoring.atomic_depth.AtomicDepth: {0} actual boxlength 125, box[113*108*125], resolution  0.504
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Pruned 683 / 8962 rotamers.
# core.pack.pack_rotamers: {0} built 8279 rotamers at 163 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -652.043  1.13573  1.13573  0.30745
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -644.176  1.13573  1.13573  0.31955
# protocols.relax.FastRelax: {0} CMD: min  -681.985  1.05207  1.05207  0.31955
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -681.985  1.05207  1.05207  0.31955
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -605.207  1.05207  1.05207  0.55
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Building hbond graph
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Hbond graph has: 12098 edges requiring: 5075928 bytes
# core.chemical.AtomICoor: {0} [ WARNING ] IcoorAtomID::atom_id(): Cannot get atom_id for POLYMER_LOWER of residue LEU 1.  Returning BOGUS ID instead.
# core.conformation.Residue: {0} [ WARNING ] missing an atom: 1  H   that depends on a nonexistent polymer connection!
# core.conformation.Residue: {0} [ WARNING ]  --> generating it using idealized coordinates.
# core.scoring.atomic_depth.AtomicDepth: {0} actual boxlength 126, box[114*109*126], resolution  0.504
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Pruned 713 / 8531 rotamers.
# core.pack.pack_rotamers: {0} built 7818 rotamers at 161 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -602.743  1.05207  1.05207  0.55
# protocols.relax.FastRelax: {0} CMD: min  -625.219  1.0528  1.0528  0.55
# protocols.relax.FastRelax: {0} MRP: 0  -625.219  -625.219  1.0528  1.0528
# protocols.relax.FastRelax: {0} CMD: accept_to_best  -625.219  1.0528  1.0528  0.55
# protocols.relax.FastRelax: {0} CMD: endrepeat  -625.219  1.0528  1.0528  0.55
# protocols.relax.FastRelax: {0} Using CartesianMinizer with lbfgs
# protocols.relax.FastRelax: {0} CMD: switch:cartesian  -625.219  1.0528  1.0528  0.55
# protocols.relax.FastRelax: {0} CMD: repeat  -625.219  1.0528  1.0528  0.55
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -625.219  1.0528  1.0528  0.55
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -736.189  1.0528  1.0528  0.022
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Building hbond graph
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Hbond graph has: 14804 edges requiring: 6545144 bytes
# core.chemical.AtomICoor: {0} [ WARNING ] IcoorAtomID::atom_id(): Cannot get atom_id for POLYMER_LOWER of residue LEU 1.  Returning BOGUS ID instead.
# core.conformation.Residue: {0} [ WARNING ] missing an atom: 1  H   that depends on a nonexistent polymer connection!
# core.conformation.Residue: {0} [ WARNING ]  --> generating it using idealized coordinates.
# core.scoring.atomic_depth.AtomicDepth: {0} actual boxlength 126, box[115*110*126], resolution  0.504
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Pruned 1189 / 11589 rotamers.
# core.pack.pack_rotamers: {0} built 10400 rotamers at 161 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -750.338  1.0528  1.0528  0.022
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -746.697  1.0528  1.0528  0.02805
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 89 BRANCH 1
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 108 BRANCH 1
# protocols.relax.FastRelax: {0} CMD: min  -881.463  1.33024  1.33024  0.02805
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -881.463  1.33024  1.33024  0.02805
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -638.9  1.33024  1.33024  0.14575
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Building hbond graph
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Hbond graph has: 11739 edges requiring: 5999440 bytes
# core.chemical.AtomICoor: {0} [ WARNING ] IcoorAtomID::atom_id(): Cannot get atom_id for POLYMER_LOWER of residue LEU 1.  Returning BOGUS ID instead.
# core.conformation.Residue: {0} [ WARNING ] missing an atom: 1  H   that depends on a nonexistent polymer connection!
# core.conformation.Residue: {0} [ WARNING ]  --> generating it using idealized coordinates.
# core.scoring.atomic_depth.AtomicDepth: {0} actual boxlength 124, box[114*107*124], resolution  0.504
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Pruned 822 / 10815 rotamers.
# core.pack.pack_rotamers: {0} built 9993 rotamers at 164 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -645.57  1.33024  1.33024  0.14575
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -630.554  1.33024  1.33024  0.154
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 89 BRANCH 1
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 108 BRANCH 1
# protocols.relax.FastRelax: {0} CMD: min  -768.83  1.18778  1.18778  0.154
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -768.83  1.18778  1.18778  0.154
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -694.298  1.18778  1.18778  0.30745
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Building hbond graph
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Hbond graph has: 12273 edges requiring: 5563792 bytes
# core.chemical.AtomICoor: {0} [ WARNING ] IcoorAtomID::atom_id(): Cannot get atom_id for POLYMER_LOWER of residue LEU 1.  Returning BOGUS ID instead.
# core.conformation.Residue: {0} [ WARNING ] missing an atom: 1  H   that depends on a nonexistent polymer connection!
# core.conformation.Residue: {0} [ WARNING ]  --> generating it using idealized coordinates.
# core.scoring.atomic_depth.AtomicDepth: {0} actual boxlength 125, box[114*109*125], resolution  0.504
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Pruned 778 / 9682 rotamers.
# core.pack.pack_rotamers: {0} built 8904 rotamers at 163 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -689.028  1.18778  1.18778  0.30745
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -682.936  1.18778  1.18778  0.31955
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 89 BRANCH 1
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 108 BRANCH 1
# protocols.relax.FastRelax: {0} CMD: min  -709.173  1.11132  1.11132  0.31955
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -709.173  1.11132  1.11132  0.31955
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -642.49  1.11132  1.11132  0.55
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Building hbond graph
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Hbond graph has: 12339 edges requiring: 5245160 bytes
# core.chemical.AtomICoor: {0} [ WARNING ] IcoorAtomID::atom_id(): Cannot get atom_id for POLYMER_LOWER of residue LEU 1.  Returning BOGUS ID instead.
# core.conformation.Residue: {0} [ WARNING ] missing an atom: 1  H   that depends on a nonexistent polymer connection!
# core.conformation.Residue: {0} [ WARNING ]  --> generating it using idealized coordinates.
# core.scoring.atomic_depth.AtomicDepth: {0} actual boxlength 125, box[115*109*125], resolution  0.504
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Pruned 741 / 8892 rotamers.
# core.pack.pack_rotamers: {0} built 8151 rotamers at 162 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# ...
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -555.058  0.73874  0.73874  0.14575
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Building hbond graph
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Hbond graph has: 12995 edges requiring: 6249944 bytes
# core.chemical.AtomICoor: {0} [ WARNING ] IcoorAtomID::atom_id(): Cannot get atom_id for POLYMER_LOWER of residue LEU 1.  Returning BOGUS ID instead.
# core.conformation.Residue: {0} [ WARNING ] missing an atom: 1  H   that depends on a nonexistent polymer connection!
# core.conformation.Residue: {0} [ WARNING ]  --> generating it using idealized coordinates.
# core.scoring.atomic_depth.AtomicDepth: {0} actual boxlength 119, box[103*110*119], resolution  0.504
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Pruned 828 / 11575 rotamers.
# core.pack.pack_rotamers: {0} built 10747 rotamers at 164 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -560.007  0.73874  0.73874  0.14575
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -546.109  0.73874  0.73874  0.154
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 92 BRANCH 1
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 143 BRANCH 1
# protocols.relax.FastRelax: {0} CMD: min  -664.945  0.54222  0.54222  0.154
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -664.945  0.54222  0.54222  0.154
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -590.652  0.54222  0.54222  0.30745
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Building hbond graph
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Hbond graph has: 7434 edges requiring: 4864776 bytes
# core.chemical.AtomICoor: {0} [ WARNING ] IcoorAtomID::atom_id(): Cannot get atom_id for POLYMER_LOWER of residue LEU 1.  Returning BOGUS ID instead.
# core.conformation.Residue: {0} [ WARNING ] missing an atom: 1  H   that depends on a nonexistent polymer connection!
# core.conformation.Residue: {0} [ WARNING ]  --> generating it using idealized coordinates.
# core.scoring.atomic_depth.AtomicDepth: {0} actual boxlength 119, box[103*111*119], resolution  0.504
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Pruned 824 / 10179 rotamers.
# core.pack.pack_rotamers: {0} built 9355 rotamers at 158 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -590.886  0.54222  0.54222  0.30745
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -585.029  0.54222  0.54222  0.31955
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 92 BRANCH 1
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 143 BRANCH 1
# protocols.relax.FastRelax: {0} CMD: min  -607.341  0.456151  0.456151  0.31955
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -607.341  0.456151  0.456151  0.31955
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -540.48  0.456151  0.456151  0.55
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Building hbond graph
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Hbond graph has: 5091 edges requiring: 3990376 bytes
# core.chemical.AtomICoor: {0} [ WARNING ] IcoorAtomID::atom_id(): Cannot get atom_id for POLYMER_LOWER of residue LEU 1.  Returning BOGUS ID instead.
# core.conformation.Residue: {0} [ WARNING ] missing an atom: 1  H   that depends on a nonexistent polymer connection!
# core.conformation.Residue: {0} [ WARNING ]  --> generating it using idealized coordinates.
# core.scoring.atomic_depth.AtomicDepth: {0} actual boxlength 119, box[103*112*119], resolution  0.504
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Pruned 740 / 8450 rotamers.
# core.pack.pack_rotamers: {0} built 7710 rotamers at 158 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -521.378  0.456151  0.456151  0.55
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 92 BRANCH 1
# core.pose.util: {0} [ WARNING ] Unable to find atom_tree atom for this Rosetta branch connection angle: residue 143 BRANCH 1
# protocols.relax.FastRelax: {0} CMD: min  -545.352  0.417719  0.417719  0.55
# protocols.relax.FastRelax: {0} MRP: 1  -545.352  -547.189  0.396031  0.396031
# protocols.relax.FastRelax: {0} CMD: accept_to_best  -545.352  0.417719  0.417719  0.55
# protocols.relax.FastRelax: {0} CMD: endrepeat  -545.352  0.417719  0.417719  0.55
# protocols::checkpoint: {0} Deleting checkpoints of FastRelax
# protocols.rosetta_scripts.ParsedProtocol: {0} =======================BEGIN FILTER rmsd_cart=======================
# protocols.rosetta_scripts.ParsedProtocol: {0} =======================END FILTER rmsd_cart=======================
# protocols.rosetta_scripts.ParsedProtocol: {0} setting status to success
# protocols.rosetta_scripts.ParsedProtocol.REPORT: {0} ============Begin report for rmsd_cart==================
# protocols.rosetta_scripts.ParsedProtocol.REPORT: {0} RMSD: 0.408697
# ============End report for rmsd_cart==================
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Validating input script...
# protocols.rosetta_scripts.RosettaScriptsParser: {0} ...done
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Parsed script:
# <ROSETTASCRIPTS>
# 	<SCOREFXNS>
# 		<ScoreFunction name="sfxn" weights="beta_nov16"/>
# 		<ScoreFunction name="sfxn_cart" weights="beta_nov16_cart"/>
# 	</SCOREFXNS>
# 	<RESIDUE_SELECTORS>
# 		<True name="all"/>
# 		<ResidueName name="CYS" residue_name3="CYS,CYD"/>
# 		<Not name="not_CYS" selector="CYS"/>
# 		<Index name="new_loop_resis" resnums="98,99,100"/>
# 		<Neighborhood distance="8.0" name="around_new_loop" selector="new_loop_resis"/>
# 		<SSElement chain="A" name="design" reassign_short_terminal_loop="2" selection="3,H,S" to_selection="-3,H,E"/>
# 		<Not name="not_design" selector="design"/>
# 		<Neighborhood distance="8.0" include_focus_in_subset="0" name="pack" selector="design"/>
# 		<Not name="not_pack" selector="pack"/>
# 		<And name="lock_selector" selectors="not_pack,not_design"/>
# 	</RESIDUE_SELECTORS>
# 	<TASKOPERATIONS>
# 		<PruneBuriedUnsats allow_even_trades="false" atomic_depth_cutoff="3.5" minimum_hbond_energy="-1.0" name="prune"/>
# 		<LimitAromaChi2 chi2max="110" chi2min="70" include_trp="True" name="arochi"/>
# 		<ExtraRotamersGeneric ex1="1" ex2="1" name="ex1_ex2"/>
# 		<OperateOnResidueSubset name="lock" selector="lock_selector">
# 			<PreventRepackingRLT/>
# 		</OperateOnResidueSubset>
# 	</TASKOPERATIONS>
# 	<FILTERS>
# 		<Geometry confidence="0" count_bad_residues="true" name="geometry"/>
# 		<Geometry confidence="0" count_bad_residues="true" name="geometry_loop" residue_selector="around_new_loop"/>
# 		<Rmsd by_aln="0" chains="A" confidence="0" name="rmsd_dual" reference_name="before_relax" superimpose="0" threshold="5"/>
# 		<worst9mer confidence="0" name="9mer" rmsd_lookup_threshold="0.4"/>
# 	</FILTERS>
# 	<MOVERS>
# 		<SavePoseMover name="save_before_relax" reference_name="before_relax" restore_pose="0"/>
# 		<FastRelax bondangle="true" bondlength="true" dualspace="true" name="relax" relaxscript="MonomerRelax2019" repeats="2" scorefxn="sfxn_cart" task_operations="arochi,prune,ex1_ex2,lock">
# 			<MoveMap bb="false" chi="false" jump="false" name="mm">
# 				<ResidueSelector bb="false" bondangle="false" bondlength="false" chi="false" selector="all"/>
# 				<ResidueSelector bb="false" bondangle="false" bondlength="false" chi="true" selector="pack"/>
# 				<ResidueSelector bb="true" bondangle="false" bondlength="false" chi="true" selector="design"/>
# 				<ResidueSelector bb="true" bondangle="true" bondlength="true" chi="true" selector="CYS"/>
# 			</MoveMap>
# 		</FastRelax>
# 	</MOVERS>
# 	<PROTOCOLS>
# 		<Add mover="save_before_relax"/>
# 		<Add mover="relax"/>
# 		<Add filter="geometry"/>
# 		<Add filter="geometry_loop"/>
# 		<Add filter="rmsd_dual"/>
# 		<Add filter="9mer"/>
# 	</PROTOCOLS>
# 	<OUTPUT scorefxn="sfxn"/>
# </ROSETTASCRIPTS>
# core.scoring.ScoreFunctionFactory: {0} SCOREFUNCTION: beta_nov16.wts
# protocols.jd2.parser.ScoreFunctionLoader: {0} defined score function "sfxn" with weights "beta_nov16"
# protocols.jd2.parser.ScoreFunctionLoader: {0} defined score function "sfxn_cart" with weights "beta_nov16_cart"
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "prune" of type PruneBuriedUnsats
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "arochi" of type LimitAromaChi2
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "ex1_ex2" of type ExtraRotamersGeneric
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "lock" of type OperateOnResidueSubset
# core.select.residue_selector.util: {0} [ WARNING ] Selector name is empty!
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined filter named "geometry" of type Geometry
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined filter named "geometry_loop" of type Geometry
# core.pose.ref_pose: {0} Loading PDB: before_relax
# protocols.protein_interface_design.filters.RmsdFilter: {0} RMSD filter with superimpose=0 and threshold=5
# protocols.protein_interface_design.filters.RmsdFilter: {0} selected residues
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined filter named "rmsd_dual" of type Rmsd
# protocols.filters.LeastNativeLike9merFilter: {0} Structures which has the best fragment RMSD at the worst position greater than 99 will be filtered.
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined filter named "9mer" of type worst9mer
# core.pose.ref_pose: {0} Loading PDB: before_relax
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined mover named "save_before_relax" of type SavePoseMover
# core.scoring.ScoreFunctionFactory: {0} SCOREFUNCTION: beta_nov16.wts
# core.pack.task.xml_util: {0} Object relax reading the following task_operations: Adding the following task operations
# arochi prune ex1_ex2 lock
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined mover named "relax" of type FastRelax
# protocols.rosetta_scripts.ParsedProtocol: {0} ParsedProtocol mover with the following settings
# protocols.rosetta_scripts.ParsedProtocol: {0} Added mover "save_before_relax"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added mover "relax"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added filter "geometry"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added filter "geometry_loop"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added filter "rmsd_dual"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added filter "9mer"
# core.scoring.ScoreFunctionFactory: {0} SCOREFUNCTION: beta_nov16.wts
# protocols.jd2.parser.ScoreFunctionLoader: {0} defined score function "sfxn" with weights "beta_nov16"
# protocols.jd2.parser.ScoreFunctionLoader: {0} defined score function "sfxn_cart" with weights "beta_nov16_cart"
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "prune" of type PruneBuriedUnsats
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "arochi" of type LimitAromaChi2
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "ex1_ex2" of type ExtraRotamersGeneric
# protocols.jd2.parser.TaskOperationLoader: {0} Defined TaskOperation named "lock" of type OperateOnResidueSubset
# core.select.residue_selector.util: {0} [ WARNING ] Selector name is empty!
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined filter named "geometry" of type Geometry
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined filter named "geometry_loop" of type Geometry
# core.pose.ref_pose: {0} Loading PDB: before_relax
# protocols.protein_interface_design.filters.RmsdFilter: {0} RMSD filter with superimpose=0 and threshold=5
# protocols.protein_interface_design.filters.RmsdFilter: {0} selected residues
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined filter named "rmsd_dual" of type Rmsd
# protocols.filters.LeastNativeLike9merFilter: {0} Structures which has the best fragment RMSD at the worst position greater than 99 will be filtered.
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined filter named "9mer" of type worst9mer
# core.pose.ref_pose: {0} Loading PDB: before_relax
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined mover named "save_before_relax" of type SavePoseMover
# core.scoring.ScoreFunctionFactory: {0} SCOREFUNCTION: beta_nov16.wts
# core.pack.task.xml_util: {0} Object relax reading the following task_operations: Adding the following task operations
# arochi prune ex1_ex2 lock
# protocols.rosetta_scripts.RosettaScriptsParser: {0} Defined mover named "relax" of type FastRelax
# protocols.rosetta_scripts.ParsedProtocol: {0} ParsedProtocol mover with the following settings
# protocols.rosetta_scripts.ParsedProtocol: {0} Added mover "save_before_relax"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added mover "relax"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added filter "geometry"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added filter "geometry_loop"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added filter "rmsd_dual"
# protocols.rosetta_scripts.ParsedProtocol: {0} Added filter "9mer"
# protocols.rosetta_scripts.ParsedProtocol: {0} =======================BEGIN MOVER SavePoseMover - save_before_relax=======================
# protocols.rosetta_scripts.ParsedProtocol: {0} =======================BEGIN MOVER FastRelax - relax=======================
# core.energy_methods.CartesianBondedEnergy: {0} Creating new peptide-bonded energy container (200)
# protocols.relax.FastRelax: {0} Using AtomTreeMinimizer
# protocols.relax.FastRelax: {0} CMD: switch:torsion  -502.287  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: repeat  -502.287  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: coord_cst_weight  -502.287  0  0  0.55
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -653.316  0  0  0.022
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Building hbond graph
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Hbond graph has: 4613 edges requiring: 4451208 bytes
# core.chemical.AtomICoor: {0} [ WARNING ] IcoorAtomID::atom_id(): Cannot get atom_id for POLYMER_LOWER of residue LEU 1.  Returning BOGUS ID instead.
# core.conformation.Residue: {0} [ WARNING ] missing an atom: 1  H   that depends on a nonexistent polymer connection!
# core.conformation.Residue: {0} [ WARNING ]  --> generating it using idealized coordinates.
# core.scoring.atomic_depth.AtomicDepth: {0} actual boxlength 119, box[103*113*119], resolution  0.504
# protocols.task_operations.PruneBuriedUnsatsOperation: {0} Pruned 1084 / 9925 rotamers.
# core.pack.pack_rotamers: {0} built 8841 rotamers at 158 positions.
# core.pack.pack_rotamers: {0} Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: {0} Instantiating DensePDInteractionGraph
# core.pack.rotamer_set.RotamerSets: {0} Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# protocols.relax.FastRelax: {0} CMD: repack  -677.398  0  0  0.022
# protocols.relax.FastRelax: {0} CMD: scale:fa_rep  -672.168  0  0  0.02805

# %% [markdown]
# # Setup Dask
# Trying a adaptive SLURMCluster. to see the dashboard, forward port `8787` to `8000`:
# `local$ ssh -L 8000:localhost:8787 $USER@$HOSTNAME`
# now, the web UI is visible at `localhost:8000`
# if you're using a local cluster make sure the node this notebook is on has the same
# number of workers as cores

# %%
# !echo $HOSTNAME
# !echo $USER
# Out:
# dig64
# pleung

# %%
from dask.distributed import Client
from dask_jobqueue import SLURMCluster

cluster = SLURMCluster(cores=1,
                       processes=1,
                       job_cpu=1,
                       memory="6GB",
                       queue="medium",
                       walltime="23:30:00",
                      )
print(cluster.job_script())
# scale between 0 and 500 workers as needed
cluster.adapt(minimum=0, maximum=500) 
client = Client(cluster)
client
# Out:
# #!/usr/bin/env bash
#
# #SBATCH -J dask-worker
# #SBATCH -e /home/pleung/logs/slurm_logs/dask-worker-%J.err
# #SBATCH -o /home/pleung/logs/slurm_logs/dask-worker-%J.out
# #SBATCH -p short
# #SBATCH -n 1
# #SBATCH --cpus-per-task=1
# #SBATCH --mem=4G
# #SBATCH -t 30:00
#
# /home/pleung/.conda/envs/cereal/bin/python -m distributed.cli.dask_worker tcp://172.16.131.94:45583 --nthreads 1 --memory-limit 4.00GB --name name --nanny --death-timeout 60 --local-directory $TMPDIR/dask --no-nanny --no-dashboard
# <Client: 'tcp://172.16.131.94:45583' processes=0 threads=0, memory=0 B>

# %%
# client.close(); cluster.close()

# %% [markdown]
# # Set command line options, make tasks and submit to client
# previously used `-indexed_structure_store:fragment_store /home/bcov/sc/scaffold_comparison/data/ss_grouped_vall_all.h5`

# %%
import logging
import pyrosetta.distributed.io as io
from pyrosetta.distributed.cluster.core import PyRosettaCluster

logging.basicConfig(level=logging.INFO)
silents = glob(os.path.join(os.getcwd(), "03_silents/closed.silent"))

options = { 
    "-out:level": "300",
    "-in:file:silent_struct_type": "binary",
    "-holes:dalphaball": "/home/bcov/ppi/tutorial_build/main/source/external/DAlpahBall/DAlphaBall.gcc",
    "-indexed_structure_store:fragment_store": "/net/databases/VALL_clustered/connect_chains/ss_grouped_vall_helix_shortLoop.h5",
    "-dunbrack_prob_buried": "0.8",
    "-dunbrack_prob_nonburied": "0.8", 
    "-dunbrack_prob_buried_semi": "0.8", 
    "-dunbrack_prob_nonburied_semi": "0.8",
}

def create_tasks(silents, options):
    for silent in silents:
        tasks = {"options": "-corrections::beta_nov16 true"}
        tasks["extra_options"] = options
        tasks["set_logging_handler"] = "interactive"
        tasks["-in:file:silent"] = silent
        yield tasks
        
if not os.getenv("DEBUG"):
    output_path = os.path.join(os.getcwd(), "04_staple_pair")
    PyRosettaCluster(
        tasks=create_tasks(silents, options),
        client=client,
        scratch_dir=output_path,
        output_path=output_path,
    ).distribute(protocols=[load, pack, staple, relax])
# Out:
# WARNING:root:`conda env export --prefix /home/pleung/.conda/envs/cereal` did not run successfully, so the active conda environment YML file string was not saved! It is recommended to run:
# `conda env export --prefix /home/pleung/.conda/envs/cereal > environment.yml`
# to reproduce this simulation later.
# INFO:pyrosetta.distributed:maybe_init performing pyrosetta initialization: {'options': '-run:constant_seed 1 -multithreading:total_threads 1', 'extra_options': '-mute all', 'set_logging_handler': 'interactive', 'silent': True}
# INFO:pyrosetta.rosetta:Found rosetta database at: /home/pleung/.conda/envs/cereal/lib/python3.7/site-packages/pyrosetta/database; using it....
# INFO:pyrosetta.rosetta:PyRosetta-4 2020 [Rosetta PyRosetta4.conda.linux.cxx11thread.serialization.CentOS.python37.Release 2020.50+release.1295438cd4bd2be39c9dbbfab8db669ab62415ab 2020-12-12T00:30:01] retrieved from: http://www.pyrosetta.org
# (C) Copyright Rosetta Commons Member Institutions. Created in JHU by Sergey Lyskov and PyRosetta Team.
# Warning: Use of `pyrosetta.distributed.cluster` namespace requires Anaconda (or Miniconda) to be properly installed for reproducibility of PyRosetta simulations. Please install Anaconda (or Miniconda) onto your system to enable running `which conda`. For installation instructions, visit:
# https://docs.anaconda.com/anaconda/install

# %% [markdown]
# # Look at scores
# There is certainly a less embarrassing way to do this but at least this way is vectorized, so it should scale very well

# %%
def read_scorefile(scores):
    import pandas as pd
    scores = pd.read_json(scores, orient="records", typ="frame", lines=True)
    scores = scores.T
    mat = scores.values
    n = mat.shape[0]
    dicts = list(mat[range(n), range(n)])
    index = scores.index
    tabulated_scores = pd.DataFrame(dicts, index=index)
    return tabulated_scores
    
output_path = os.path.join(os.getcwd(), "04_staple_pair")
scores = os.path.join(output_path, "scores.json")
scores_df = read_scorefile(scores)
scores_df.head()
# Out:
#                                                        bb_clash closure_type  \
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  1225.391968      lenient
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  1225.391968      lenient
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  1225.391968      lenient
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...    70.338997      lenient
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...    88.934998      lenient
#
#                                                            ddg disulfide_at  \
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  -66.462997       56,114
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  -66.462997       67,124
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  -66.462997       60,117
# /mnt/home/pleung/projects/bistable_bundle/r3/hi... -108.647003      103,162
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  -64.790001       32,171
#
#                                                     dslf_fa13  \
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...   5.438535
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  17.581094
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  18.340962
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  11.959568
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...   7.301336
#
#                                                                                                  dssp  \
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  LHHHHHHHHHHHHHHHHHHHHLLHHHHHHHHHHHHHHHHHHHHHHH...
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  LHHHHHHHHHHHHHHHHHHHHLLHHHHHHHHHHHHHHHHHHHHHHH...
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  LHHHHHHHHHHHHHHHHHHHHLLHHHHHHHHHHHHHHHHHHHHHHH...
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  LHHHHHHHHHHHHHHHHHHHHHHHHHHHLLHHHHHHHHHHHHHHHH...
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  LHHHHHHHHHHHHHHHHHHLLLLLHHHHHHHHHHHHHHHHHHHHLL...
#
#                                                          fa_atr      fa_dun  \
# /mnt/home/pleung/projects/bistable_bundle/r3/hi... -1246.568641  556.873673
# /mnt/home/pleung/projects/bistable_bundle/r3/hi... -1239.281709  552.260353
# /mnt/home/pleung/projects/bistable_bundle/r3/hi... -1234.614434  551.274022
# /mnt/home/pleung/projects/bistable_bundle/r3/hi... -1542.308456  636.919266
# /mnt/home/pleung/projects/bistable_bundle/r3/hi... -1894.323595  868.082748
#
#                                                     fa_dun_dev  fa_dun_rot  \
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...   36.574001  141.787003
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...   36.574001  141.787003
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...   36.574001  141.787003
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...   42.985001  189.647995
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...   45.569000  250.201996
#
#                                                     ...  scaffold  score  \
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  ...    TH_DHR    0.0
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  ...    TH_DHR    0.0
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  ...    TH_DHR    0.0
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  ...       DHR    0.0
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  ...       THR    0.0
#
#                                                        score_A     score_B  \
# /mnt/home/pleung/projects/bistable_bundle/r3/hi... -128.449005 -132.048004
# /mnt/home/pleung/projects/bistable_bundle/r3/hi... -128.449005 -132.048004
# /mnt/home/pleung/projects/bistable_bundle/r3/hi... -128.449005 -132.048004
# /mnt/home/pleung/projects/bistable_bundle/r3/hi... -171.576004 -186.817993
# /mnt/home/pleung/projects/bistable_bundle/r3/hi... -218.315994 -237.815002
#
#                                                     score_per_res   sfxn_used  \
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...         -2.666  beta_nov16
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...         -2.666  beta_nov16
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...         -2.666  beta_nov16
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...         -3.100  beta_nov16
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...         -2.716  beta_nov16
#
#                                                     shift  total_length  \
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...    7.0         202.0
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...    7.0         202.0
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...    7.0         202.0
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...    0.0         231.0
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...    6.0         298.0
#
#                                                     total_score  yhh_planarity
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  2632.416732       0.000000
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  2486.437685       0.000000
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  2485.949566       0.000000
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  1485.253443       0.025595
# /mnt/home/pleung/projects/bistable_bundle/r3/hi...  2520.511947       0.017626
#
# [5 rows x 52 columns]

# %%
len(scores_df)
# Out:
# 144

# %%
scores_df.columns
# Out:
# Index(['bb_clash', 'closure_type', 'ddg', 'disulfide_at', 'dslf_fa13', 'dssp',
#        'fa_atr', 'fa_dun', 'fa_dun_dev', 'fa_dun_rot', 'fa_dun_semi',
#        'fa_elec', 'fa_intra_atr_xover4', 'fa_intra_elec', 'fa_intra_rep',
#        'fa_intra_rep_xover4', 'fa_intra_sol_xover4', 'fa_rep', 'fa_sol',
#        'hbond_bb_sc', 'hbond_lr_bb', 'hbond_sc', 'hbond_sr_bb', 'hxl_tors',
#        'interface_buried_sasa', 'lk_ball', 'lk_ball_bridge',
#        'lk_ball_bridge_uncpl', 'lk_ball_iso', 'lk_ball_wtd', 'new_loop_resis',
#        'omega', 'p_aa_pp', 'parent', 'parent_length', 'pivot_helix',
#        'pre_break_helix', 'pro_close', 'rama_prepro', 'ref', 'sc', 'sc_int',
#        'scaffold', 'score', 'score_A', 'score_B', 'score_per_res', 'sfxn_used',
#        'shift', 'total_length', 'total_score', 'yhh_planarity'],
#       dtype='object')

# %%
list(scores_df["dslf_fa13"])
# Out:
# [5.438534978012019,
#  17.58109422264533,
#  18.340961881827035,
#  11.959567959218871,
#  7.30133579310764,
#  23.349278344440627,
#  1.3722084201027092,
#  20.61465137216387,
#  10.45333559825284,
#  25.379314292521027,
#  4.200967940277531,
#  41.526047025789936,
#  18.151717708539785,
#  24.19243737381412,
#  0.5983479913218901,
#  4.761877010226436,
#  16.48297454693737,
#  7.30133579310764,
#  1.3722084201027092,
#  23.349278344440627,
#  24.192437373814105,
#  4.200967940277531,
#  10.45333559825284,
#  25.379314292521027,
#  41.526047025789936,
#  16.48297454693737,
#  0.5983479913219231,
#  20.61465137216385,
#  2.652480598943569,
#  4.761877010226436,
#  18.151717708539795,
#  18.340961881827035,
#  17.58109422264533,
#  5.438534978012019,
#  23.349278344440627,
#  1.3722084201027092,
#  7.30133579310764,
#  5.7272861340190335,
#  9.02791455460266,
#  6.926120357955823,
#  9.027914554602866,
#  5.727286134019123,
#  6.926120357955944,
#  0.5983479913219231,
#  16.48297454693737,
#  18.151717708539795,
#  10.45333559825284,
#  4.761877010226436,
#  4.200967940277531,
#  24.192437373814105,
#  2.652480598943569,
#  25.379314292521027,
#  41.526047025789936,
#  20.61465137216385,
#  7.5789318877888725,
#  18.340961881827035,
#  17.58109422264533,
#  5.438534978012019,
#  5.438534978012019,
#  17.581094222645344,
#  18.340961881827027,
#  28.255819792994288,
#  5.464920457043942,
#  5.075023413860843,
#  3.955247808291692,
#  5.007479064058106,
#  8.080266959694196,
#  7.5789318877888725,
#  5.007479064058137,
#  8.080266959694239,
#  3.9552478082916753,
#  1.339715490534148,
#  6.926120357955823,
#  9.02791455460266,
#  5.7272861340190335,
#  1.3722084201027092,
#  7.30133579310764,
#  23.349278344440627,
#  7.5789318877888725,
#  1.3722084201027092,
#  23.349278344440627,
#  7.30133579310764,
#  7.57893188778889,
#  1.339715490534148,
#  3.955247808291692,
#  5.007479064058106,
#  8.080266959694196,
#  5.075023413860873,
#  28.255819792994117,
#  5.464920457043931,
#  1.339715490534148,
#  11.959567959218871,
#  6.926120357955823,
#  5.7272861340190335,
#  9.02791455460266,
#  7.57893188778889,
#  11.959567959218871,
#  11.959567959218877,
#  5.075023413860857,
#  5.464920457043965,
#  28.255819792994313,
#  5.007479064058106,
#  8.080266959694196,
#  3.955247808291692,
#  1.339715490534148,
#  5.7272861340190335,
#  6.926120357955823,
#  9.02791455460266,
#  8.080266959694196,
#  5.007479064058106,
#  3.955247808291692,
#  5.464920457043965,
#  5.075023413860857,
#  28.255819792994313,
#  1.339715490534148,
#  5.464920457043965,
#  5.075023413860857,
#  28.255819792994313,
#  4.200967940277531,
#  0.5983479913219231,
#  25.379314292521027,
#  16.48297454693737,
#  20.61465137216385,
#  18.151717708539795,
#  10.45333559825284,
#  41.526047025789936,
#  2.652480598943569,
#  24.192437373814105,
#  4.761877010226436,
#  11.959567959218871,
#  17.58109422264533,
#  5.438534978012019,
#  18.340961881827035,
#  4.200967940277531,
#  24.192437373814105,
#  4.761877010226436,
#  20.61465137216385,
#  41.526047025789936,
#  25.379314292521027,
#  10.45333559825284,
#  0.5983479913219231,
#  16.48297454693737,
#  18.151717708539795,
#  2.652480598943569]
